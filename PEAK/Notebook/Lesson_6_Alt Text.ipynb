# %% [markdown]
# # Performing Domain Analysis with AI
# ## Leveraga SA Model, Write Up, and Results on Strategy to develop a first cut Architecture
#
# First we load up the PEAK Model

# %% [markdown]
# ### Model-Specific Code (Do Not Modify)
#
# This section contains code that is specific to the system model. It is updated only when the model is changed and should not require user modifications under normal circumstances.
#
# If a new model is introduced, ensure this section is reviewed and updated as needed.

# %%
#!pip install --upgrade git+https://github.com/tkSDISW/Capella_Tools 
import capellambse.decl

from capella_tools import capellambse_helper

from IPython import display as diag_display
resources = {
    "PEAK": "PEAK/PEAK",
}
path_to_model = "../PEAK.aird"
model = capellambse.MelodyModel(path_to_model, resources=resources)
from capella_tools import Pub4C
# Instantiate the class with the traceability file
traceability_store = Pub4C.Traceability_Store("../PEAK/traceability")
# Out:
# Warning: File '../PEAK/traceability' does not exist.

# %% [markdown]
# ## 🔄 Embedding Generation Process
#
# Next we load evaluate whether we ne to update the embedings. If there older than model we will update thems. 🚀

# %%
from capella_tools  import capella_embeddings_manager

# Generate embeddings for all objects
model_embedding_manager = capella_embeddings_manager.EmbeddingManager()

embedding_file = "embeddings.json" 
model_embedding_manager.set_files( path_to_model , embedding_file)

model_embedding_manager.create_model_embeddings(model)
# Out:
# ✅ EmbeddingManager initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: Default
# 🤖 Model: gpt-4o
# Loading embeddings
# embeddings loaded.

# %% [markdown]
# ## 🎯 Define the model element or diagram for analysis.
#
# We use the embedding to locate a diagram that will be used for basis of analysis. It a OCB diagrams with relations to all the functional chains.
#
# > 💡 **Tip:** If you're unsure about the model structure, review the documentation or refer to the model's diagrams for additional guidance.

# %%
import os
from openai import OpenAI
from IPython.core.display import HTML
from IPython.display import display, clear_output, Markdown, IFrame
from capella_tools  import Open_AI_RAG_manager

selected_objects = model_embedding_manager.query_and_select_top_objects("[SAB] Water Generation QAS requirements", top_n=1)
#Workflow
from capella_tools import capellambse_yaml_manager
yaml_handler = capellambse_yaml_manager.CapellaYAMLHandler()
   
#Generate YAML for the logical component and append to the file
for object in  selected_objects :  
    yaml_handler.generate_yaml(model.by_uuid(object["uuid"]))  

yaml_handler.generate_traceability_related_objects(model,traceability_store)

#yaml_handler.display()
yaml_handler.generate_yaml_referenced_objects()
#yaml_handler.display()

yaml_handler.write_output_file()



#print(object)
# Step 1: Get YAML content
yaml_content = yaml_handler.get_yaml_content()

# Step 2: Invoke ChatGPT for analysis
analyzer = Open_AI_RAG_manager.ChatGPTAnalyzer(yaml_content)#analyzer.add_text_file_to_messages("PEAK System.docx")
prompt = """
Write image description for the visually impaired based on the content of this diagram. Specifically call attention to how the PEAK supports Water Management functional chain.
Include a list of all requirement related to the functional chain. 
"""
analyzer.follow_up_prompt(prompt)
chatgpt_response = analyzer.get_response()
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
#
# This is a list of ranked Objects Based on Query:
# Index: 0, Name: [SAB] Water Generation QAS requirements, Similarity: 0.86, Type: Diagram, Phase: System Analysis SA, Source: , Target:
# ✅ ChatGPTAnalyzer initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: Default
# 🤖 Model: gpt-4o
# **Your prompt:**
# Write image description for the visually impaired based on the content of this diagram. Specifically call attention to how the PEAK supports Water Management functional chain.
# Include a list of all requirement related to the functional chain.
# **Response:**
#
# This YAML document describes a comprehensive system model that revolves around a Water Management functional chain, represented as part of a broader system called "PEAK." The Water Management functional chain comprises multiple system functions, including "Provide Water," "Receive Water," and "Operate System," which interact through functional exchanges. The PEAK supports this functional chain by facilitating and allocating several functions and exchanges necessary for efficient water management, ensuring the provision and reception of water in various contexts, such as aiding local populations or operational user communities.
#
# The description outlines numerous interactions within the system:
#
# 1. **Provide Water (SystemFunction):**
#    - Inputs and outputs are involved in managing water production and distribution through functional exchanges.
#    - Exchanges include managing water production, delivering filtered and potable water, and ensuring effective water distribution.
#
# 2. **Receive Water (SystemFunction):**
#    - Involves receiving water from the Provide Water function for use by First Responders, Local Population, and more.
#    - Outputs water for consumption and assistance to local populations.
#
# 3. **Operate System (SystemFunction):**
#    - Plays a critical role in managing the overall water production process within the chain.
#    - Responsible for system operation, ensuring the effective management of water production inputs and outputs.
#
# The PEAK component is vital in supporting the Water Management functional chain as it integrates multiple system components and functional interactions. This integration enables efficient water distribution and ensures that various system components, such as First Responders and Aid Personnel, can effectively use and manage water resources.
#
# **Requirements Related to the Water Management Functional Chain:**
#
# 1. **Filtration System Inclusion:**
#    The water system shall include a filtration system to ensure contaminant removal.
#
# 2. **Water Distribution Capability:**
#    The system shall include water distribution capabilities.
#
# 3. **Include Storage Container:**
#    The water system shall include a storage container for purified water storage.
#
# 4. **Kit Power Source:**
#    The water equipment shall be powered through the kit power generation system.
#
# 5. **Leverage Existing Water Tech:**
#    The water system shall leverage existing technology to reduce development time and cost.
#
# 6. **Produce Potable Water:**
#    The purification equipment shall produce potable water to meet health and hygiene needs.
#
# 7. **Advanced Water Sensors:**
#    Water systems shall have advanced sensors for quality monitoring to ensure safety and compliance.
#
# These requirements underscore the functional chain's emphasis on the efficient and effective distribution, management, and use of water resources, as facilitated by the system's functional interactions and the supportive framework provided by PEAK.
# **Token Usage Info:**
#
# Tokens used: prompt=47673, completion=512, total=48185

# %%
import os
from openai import OpenAI
from IPython.core.display import HTML
from IPython.display import display, clear_output, Markdown, IFrame
from capella_tools  import Open_AI_RAG_manager

selected_objects = model_embedding_manager.query_and_select_top_objects("[SAB] Situational Awareness and requirements", top_n=1)
#Workflow
from capella_tools import capellambse_yaml_manager
yaml_handler = capellambse_yaml_manager.CapellaYAMLHandler()
   
#Generate YAML for the logical component and append to the file
for object in  selected_objects :  
    yaml_handler.generate_yaml(model.by_uuid(object["uuid"]))  

yaml_handler.generate_traceability_related_objects(model,traceability_store)

#yaml_handler.display()
yaml_handler.generate_yaml_referenced_objects()
#yaml_handler.display()

yaml_handler.write_output_file()



#print(object)
# Step 1: Get YAML content
yaml_content = yaml_handler.get_yaml_content()

# Step 2: Invoke ChatGPT for analysis
analyzer = Open_AI_RAG_manager.ChatGPTAnalyzer(yaml_content)#analyzer.add_text_file_to_messages("PEAK System.docx")
prompt = """
Write image description for the visually impaired based on the content of this diagram. Specifically call attention to how the PEAK supports Situational Awareness functional chain.
Include a list of all requirement related to the functional chain. 
"""
analyzer.follow_up_prompt(prompt)
chatgpt_response = analyzer.get_response()
# Out:
# This is a list of ranked Objects Based on Query:
# Index: 0, Name: [SAB] Situational Awareness and requirements, Similarity: 0.83, Type: Diagram, Phase: System Analysis SA, Source: , Target:
# ✅ ChatGPTAnalyzer initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: Default
# 🤖 Model: gpt-4o
# **Your prompt:**
# Write image description for the visually impaired based on the content of this diagram. Specifically call attention to how the PEAK supports Situational Awareness functional chain.
# Include a list of all requirement related to the functional chain.
# **Response:**
#
# **Image Description:**
#
# The diagram outlines a complex system architecture with a focus on the functional chain for "Situational Awareness" within a larger framework titled "[SAB] Situational Awareness and requirements." The central component highlighted is "PEAK," which plays a critical role in supporting and facilitating situational awareness operations.
#
# **Key Elements:**
#
# 1. **Central Component - PEAK:**
#    - PEAK is identified as a "SystemComponent" within the diagram and is responsible for managing and facilitating various system functions related to situational awareness.
#    - It includes functions like "Provide Situational Awareness," "Provide Communication management," "Provide Power," and others that collectively support the broader situational awareness and emergency response efforts.
#
# 2. **Functional Chain - Provide Situational Awareness:**
#    - This chain starts with the "Operate System" which outputs "Manager Situational Awareness" and feeds into "Provide Situational Awareness."
#    - "Provide Situational Awareness" in turn has various outputs like "Comms," "Recon," and "Monitor Environment," which are essential for achieving comprehensive situational awareness.
#    - These functions ensure that data from the environment is gathered, analyzed, and communicated effectively to respond to dynamic situations faster.
#
# 3. **Involvement of Other Components:**
#    - The diagram also shows collaboration with other system components like "Partner Nation Environment" and "First Responders," which utilize situational data provided by PEAK.
#    - System functions like "Perform Aerial Recon" and "Monitor Environment" are part of these collaborations, demonstrating the integrated approach to situational awareness.
#
# **List of Requirements Related to the Situational Awareness Functional Chain:**
#
# 1. **Include Camera System:**
#    - The situational awareness component shall include a camera system to capture essential visual data.
#
# 2. **Integrate Situational Platform:**
#    - The component shall have an integrated platform to provide a cohesive data framework.
#
# 3. **Power Through Kit:**
#    - The system shall be powered through the kit to ensure system autonomy.
#
# 4. **Existing Awareness Tech:**
#    - Leverage existing technology to optimize existing capabilities.
#
# 5. **GIS Integration:**
#    - Integration with Geographic Information Systems to enhance mapping and tracking capabilities.
#
# 6. **Weather Forecast Alerts:**
#    - Components shall issue alerts based on forecasted weather conditions to prepare users for imminent conditions.
#
# 7. **Situational Awareness Features:**
#    - Include local situational awareness capabilities to provide essential data to responders.
#
# 8. **Transmit Situation Reports:**
#    - Enable transmitting situation reports to keep authorities and aid personnel informed.
#
# 9. **Integrate Communications:**
#    - The communications system shall integrate with the situational awareness component for streamlined operations.
#
# 10. **Weather Data Integration:**
#     - Components shall integrate local weather data streams to provide environmental context for operations.
#
# The diagram emphasizes a coherent network of functions and components working together under the PEAK system to enhance situational awareness, ensuring that decision-makers and responders have the critical information they need during crisis scenarios. Each requirement focuses on enhancing the capability and reach of the situational awareness system, ensuring it can operate effectively in diverse environments.
# **Token Usage Info:**
#
# Tokens used: prompt=55877, completion=637, total=56514

# %%
import os
from openai import OpenAI
from IPython.core.display import HTML
from IPython.display import display, clear_output, Markdown, IFrame
from capella_tools  import Open_AI_RAG_manager

selected_objects = model_embedding_manager.query_and_select_top_objects("[SAB] Comms Requirements", top_n=1)
#Workflow
from capella_tools import capellambse_yaml_manager
yaml_handler = capellambse_yaml_manager.CapellaYAMLHandler()
   
#Generate YAML for the logical component and append to the file
for object in  selected_objects :  
    yaml_handler.generate_yaml(model.by_uuid(object["uuid"]))  

yaml_handler.generate_traceability_related_objects(model,traceability_store)

#yaml_handler.display()
yaml_handler.generate_yaml_referenced_objects()
#yaml_handler.display()

yaml_handler.write_output_file()



#print(object)
# Step 1: Get YAML content
yaml_content = yaml_handler.get_yaml_content()

# Step 2: Invoke ChatGPT for analysis
analyzer = Open_AI_RAG_manager.ChatGPTAnalyzer(yaml_content)#analyzer.add_text_file_to_messages("PEAK System.docx")
prompt = """
Write image description for the visually impaired based on the content of this diagram. Specifically call attention to how the PEAK supports Provide Communication, Provide National and Regional Comms, Provide Local Commuinications functional chain.
Include a list of all requirement related to each functional chain. 
"""
analyzer.follow_up_prompt(prompt)
chatgpt_response = analyzer.get_response()
# Out:
# This is a list of ranked Objects Based on Query:
# Index: 0, Name: [SAB]  Comms Requirements, Similarity: 0.80, Type: Diagram, Phase: System Analysis SA, Source: , Target:
# ✅ ChatGPTAnalyzer initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: Default
# 🤖 Model: gpt-4o
# **Your prompt:**
# Write image description for the visually impaired based on the content of this diagram. Specifically call attention to how the PEAK supports Provide Communication, Provide National and Regional Comms, Provide Local Commuinications functional chain.
# Include a list of all requirement related to each functional chain.
# **Response:**
#
# **Image Description for the Visually Impaired:**
#
# The diagram focuses on three primary functional chains supported by the PEAK system: Provide Communication, Provide National and Regional Comms, and Provide Local Communications. Here's an overview of each chain and their associated components and requirements:
#
# 1. **Provide Communication Functional Chain:**
#    - **Components Involved:**
#      - **Provide Communication management**: This function centralizes communication efforts and distributes them across different services and systems.
#      - **Operate System**: It is responsible for overseeing communication systems and ensuring their correct implementation.
#      - **Provide Communication Services**: This function extends the communication capabilities to designated services like mobile and comm services.
#      - **Manage Data**: Involves handling communication data for further processing and distribution across platforms.
#      - **Functional Exchanges**: Key interactions include Cellular connectivity, managing communication services, and operations.
#
#    - **Related Requirements:**
#      - Integrate Communications: Ensures streamlined operations with situational awareness components.
#      - Secure Communications: Ensures confidentiality and integrity of communication.
#      - Low-Bandwidth Communications: Optimizes data transmission in variable network conditions.
#      - High Throughput Data Capacity: Allows for image and video sharing.
#      - Network Adaptive Protocols: Adapts communication protocols to varying network conditions.
#      - Power Communications: Ensures communication systems are powered through the kit for consistent operation.
#
# 2. **Provide National and Regional Comms Functional Chain:**
#    - **Components Involved:**
#      - **Provide National and Regial communications**: Manages and facilitates communication at broader levels, integrating with regional networks.
#      - **Regional National Comms**: Acts as a bridge within the national-regional communication efforts.
#
#    - **Related Requirements:**
#      - Communications Levels: Ensures operation on various communication levels.
#      - Mesh Network Capability: Supports extended network capabilities for broader communication coverage.
#      - Leverage Existing Communication Tech: Utilizes existing technologies for efficiency.
#      - Coordinate with Public Entities: Facilitates interaction with public bodies for integrated responses.
#
# 3. **Provide Local Communications Functional Chain:**
#    - **Components Involved:**
#      - **Local Communications**: Focuses on locally-oriented communication services tailored to the community needs.
#      - **Provide Communication management**: Plays a vital role in the distribution and management of local communications.
#
#    - **Related Requirements:**
#      - Public Access Points: Provides emergency communication access points for public use.
#      - Public Information Broadcast: Includes public information broadcast channels for awareness.
#      - Collaboration with Local Authorities: Supports collaboration in local regions to ensure alignment with needs.
#      - Critical Event Focus: Centered on aiding during critical times, focusing operations on crucial events.
#
# Overall, the PEAK system, through these functional chains and supported components, aims to deliver robust and cohesive communication capabilities across local, national, and regional levels, meeting a wide range of requirements to maintain efficient and secure operations.
# **Token Usage Info:**
#
# Tokens used: prompt=51134, completion=593, total=51727

# %%
import os
from openai import OpenAI
from IPython.core.display import HTML
from IPython.display import display, clear_output, Markdown, IFrame
from capella_tools  import Open_AI_RAG_manager

selected_objects = model_embedding_manager.query_and_select_top_objects("[SAB] Power QAS with requirements ", top_n=1)
#Workflow
from capella_tools import capellambse_yaml_manager
yaml_handler = capellambse_yaml_manager.CapellaYAMLHandler()
   
#Generate YAML for the logical component and append to the file
for object in  selected_objects :  
    yaml_handler.generate_yaml(model.by_uuid(object["uuid"]))  

yaml_handler.generate_traceability_related_objects(model,traceability_store)

#yaml_handler.display()
yaml_handler.generate_yaml_referenced_objects()
#yaml_handler.display()

yaml_handler.write_output_file()



#print(object)
# Step 1: Get YAML content
yaml_content = yaml_handler.get_yaml_content()

# Step 2: Invoke ChatGPT for analysis
analyzer = Open_AI_RAG_manager.ChatGPTAnalyzer(yaml_content)#analyzer.add_text_file_to_messages("PEAK System.docx")
prompt = """
Write image description for the visually impaired based on the content of this diagram. Specifically call attention to how the PEAK supports Provide Power functional chain.
Include a list of all requirement related to each functional chain. 
List all requirements related to the PEAK component relevent to power management depicted on the diagram.
"""
analyzer.follow_up_prompt(prompt)
chatgpt_response = analyzer.get_response()
# Out:
# This is a list of ranked Objects Based on Query:
# Index: 0, Name: [SAB] Power QAS with requirments, Similarity: 0.81, Type: Diagram, Phase: System Analysis SA, Source: , Target:
# ✅ ChatGPTAnalyzer initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: Default
# 🤖 Model: gpt-4o
# **Your prompt:**
# Write image description for the visually impaired based on the content of this diagram. Specifically call attention to how the PEAK supports Provide Power functional chain.
# Include a list of all requirement related to each functional chain.
# List all requirements related to the PEAK component relevent to power management depicted on the diagram.
# **Response:**
#
# **Image Description for the Visually Impaired based on Diagram Content:**
#
# The image is a detailed system diagram illustrating the relationships and interactions within a complex power distribution and management system, specifically focusing on the PEAK component and its functional chain called "Provide Power." The components and functions are interconnected through lines representing functional exchanges, vividly demonstrating how power is managed across different system parts.
#
# In the upper section, the **PEAK component** is established as a central hub marked as a SystemComponent, identified with a primary_uuid of "ddc7faf6-4ef7-4adb-9c7b-8a55f0958947." It acts as the key provider and manager of functions related to power. Beneath the PEAK, various functions like "Provide Power," "Backup Power," "Collect Energy," and "Operate System" are arranged, depicting a flow of energy and operational responsibilities. Arrows connect these functions, indicating the power exchange routes between them and highlighting the flow from energy collection to power provision and operation.
#
# The **"Provide Power"** functional chain, labeled with a primary_uuid of "fa47f0de-5913-489d-aaab-6fb52ccb7a43," involves multiple system functions such as "Receive Power for Phone," "Operate System," "Backup Power," "Collect Energy," and their respective functional exchanges, visually emphasizing the multi-directional and interconnected pathways through which power is managed and distributed within the system.
#
# The functional exchanges particularly underscore the complexity and robustness of how power is collected, managed, and distributed back to various receiving components, maintaining an efficient energy supply chain.
#
# **List of Requirements Related to Each Functional Chain:**
#
# 1. **Provide Power Functional Chain:**
#    - Renewable Power Source: Promotes sustainability by ensuring the system runs on renewable power.
#    - Fossil Fuel Backup: Ensures the system has a fallback generator for continuous operation.
#    - Support Kit Components: Ensures the power system can sustain all kit components.
#
# 2. **Assist Population Functional Chain:**
#    - Portable Power Sources: Supports off-grid operations for continuity.
#    - Battery Backup: Incorporates a backup for critical function operations.
#    - Mission-Customizable Kits: Allows customization to fulfill mission-specific power needs.
#
# **Requirements Related to the PEAK Component Relevant to Power Management:**
#
# - Kit Power Source: Ensures the equipment is powered efficiently through the kit system.
# - Renewable Power Source: System should rely primarily on renewable sources.
# - Fossil Fuel Backup: Includes a backup generator for constant operations.
# - Support Kit Components: Power system with sufficient capacity to support components.
# - Power Communications: Kit-powered communications for consistency.
# - Power Management Interface: Interface for monitoring and efficient management.
# - Wide Range Power Input: System supports diverse input voltages.
# - Low Environmental Impact: Promotes sustainability with reduced environmental footprint.
# - Scalable Design: Allows expansion and adaptation to operational scale changes.
# - Use Existing Power Tech: Leverages existing technology to minimize resource utilization.
# - Use COTS (Commercial-Off-The-Shelf) Technology: Utilizes accessible commercial tech.
# - Easy Operation: Ensures the system can be managed by diverse personnel.
# - Low Maintenance: Designed to minimize operational sustainment costs.
# - Transportable System: Ensures the system is transportable by various modes.
#
# These requirements closely relate to the PEAK's power management capabilities as depicted in the diagram; they lay down the framework for ensuring efficient power collection, management, and distribution, emphasizing sustainability, resiliency, and operational efficiency.
# **Token Usage Info:**
#
# Tokens used: prompt=48148, completion=714, total=48862

# %% [markdown]
# ## 💬 Launch Interactive Chat on Structured Input

# %%
print("Done")
# Out:
# Done

# %% [markdown]
# #
