# %% [markdown]
# The folowing cell loads the model.

# %%
#!pip install --upgrade git+https://github.com/tkSDISW/Capella_Tools 
import capellambse.decl

from capella_tools import capellambse_helper

from IPython import display as diag_display
resources = {
    "PEAK": "PEAK/PEAK",
}
path_to_model = "../PEAK.aird"
model = capellambse.MelodyModel(path_to_model, resources=resources)
from capella_tools import Pub4C
# Instantiate the class with the traceability file
traceability_store = Pub4C.Traceability_Store("../PEAK/traceability")
# Out:
# Warning: File '../PEAK/traceability' does not exist.

# %% [markdown]
# Load the embeddings

# %%
from capella_tools  import capella_embeddings_manager

# Generate embeddings for all objects
model_embedding_manager = capella_embeddings_manager.EmbeddingManager()

embedding_file = "embeddings.json" 
model_embedding_manager.set_files( path_to_model , embedding_file)

model_embedding_manager.create_model_embeddings(model)
# Out:
# OpenAI API Key retrieved successfully.
# Creating Embeddings
# embeddings generated
# Saving embeddings

# %% [markdown]
# Locate object using embeddings.

# %%
selected_objects = model_embedding_manager.query_and_select_top_objects("[SAB] Water Power SA Comms", top_n=1)
# Out:
# This is a list of ranked Objects Based on Query:
# Index: 0, Name: [SAB] Water Power SA Comms, Similarity: 0.82, Type: Diagram, Phase: System Analysis SA, Source: , Target:

# %% [markdown]
# Create the structured input file.

# %%
#Workflow
from capella_tools import capellambse_yaml_manager
yaml_handler = capellambse_yaml_manager.CapellaYAMLHandler()
   
#Generate YAML for the logical component and append to the file
for object in  selected_objects : 
    if object["type"] == "Diagram" :
        yaml_handler.generate_yaml(model.by_uuid(object["uuid"]))  
    else:
        yaml_handler.generate_yaml( model.search(object["type"]).by_uuid(object["uuid"]))


yaml_handler.generate_traceability_related_objects(model,traceability_store)

#yaml_handler.display()
yaml_handler.generate_yaml_referenced_objects()
#yaml_handler.display()

yaml_handler.write_output_file()

# %% [markdown]
# ## Heading
# Requirement Body **Rationale:** Rationale text

# %%
import ast
#from capella_tools import Open_AI_RAG_manager
import Open_AI_RAG_manager
# Step 1: Get YAML content
yaml_content = yaml_handler.get_yaml_content()
analyzer = Open_AI_RAG_manager.ChatGPTAnalyzer(yaml_content)

analyzer.add_text_file_to_messages("PEAK System.docx")
prompt = """
Generate a set of 100 user requirements do not stop for brevity, only if no new requirements can be noted.
- Each requirment should be a tuple: (name, body, rationale).
- The name shall be five or fewer words introducing the requirement.
- The body shall be in the format of a shall statement, that is clear and concise. 
- The rationale should explain the source behind numeric requirement. 
- Output ONLY a Python list of these tuples.
- No explanation, no extra text, just the list in Python syntax.
"""

analyzer.follow_up_prompt(prompt)
requirements_text = analyzer.get_response()
print(requirements_text)
requirements = ast.literal_eval(requirements_text)
for title, statement, rationale in requirements:
    print(f"### {title}\n- **Requirement:** {statement}\n- **Rationale:** {rationale}\n")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# OpenAI API Key retrieved successfully.
# ✅ File `PEAK System.docx` added to messages for analysis.
# **Your prompt:**
# Generate a set of 100 user requirements do not stop for brevity, only if no new requirements can be noted.
# - Each requirment should be a tuple: (name, body, rationale).
# - The name shall be five or fewer words introducing the requirement.
# - The body shall be in the format of a shall statement, that is clear and concise.
# - The rationale should explain the source behind numeric requirement.
# - Output ONLY a Python list of these tuples.
# - No explanation, no extra text, just the list in Python syntax.
# **ChatGPT Response:**
#
#
# [
#     ("Use COTS Technology", "The system shall utilize commercial-off-the-shelf technology.", "Requires limited development and accessible technology."),
#     ("Easy Operation", "The system shall be easy to operate.", "To allow various personnel to manage the system."),
#     ("Low Maintenance", "The system shall require low maintenance.", "To reduce operational sustainment costs."),
#     ("Export Capability", "The system shall be exportable to foreign nations.", "For deployment in various geographic regions."),
#     ("Non-Proprietary Technology", "The system shall use non-proprietary technology.", "To ensure flexibility and interoperability."),
#     ("Lightweight Design", "The system shall be lightweight and man-portable.", "For easy transport and deployment by personnel."),
#     ("Durability", "The system shall be durable and weather resistant.", "To withstand diverse environmental conditions."),
#     ("Limited HAZMAT Needs", "The system shall have limited HAZMAT requirements.", "To reduce risks associated with hazardous materials."),
#     ("Transportable System", "The system shall be transportable by air, sea, and land modes.", "To ensure flexible logistics."),
#     ("Cargo Pallet Fit", "The system components shall fit on a single 463L cargo air pallet.", "Standardizes military air transport."),
#     ("Produce Potable Water", "The water purification equipment shall produce potable water.", "To meet health and hygiene needs."),
#     ("Filtration System Inclusion", "The water system shall include a filtration system.", "Ensures the removal of contaminants."),
#     ("Water Distribution Capability", "The system shall include water distribution capability.", "To facilitate potable water supply."),
#     ("Include Storage Container", "The water system shall include a storage container.", "To store the purified water."),
#     ("Kit Power Source", "The water equipment shall be powered through the kit power generation system.", "To ensure energy efficiency."),
#     ("Leverage Existing Water Tech", "The water system shall leverage existing technology.", "To reduce development time and cost."),
#     ("Renewable Power Source", "The power sub-system shall primarily run on renewable sources.", "To promote sustainability and autonomy."),
#     ("Fossil Fuel Backup", "The power system shall have a fossil fuel generator backup.", "Ensures continuous operation."),
#     ("Support Kit Components", "The power system shall have sufficient capacity to support all kit components.", "Enables integrated operation."),
#     ("Use Existing Power Tech", "The power system shall leverage existing technology.", "To minimize resource use."),
#     ("Situational Awareness Features", "The system shall include local situational awareness capabilities.", "To provide essential data to responders."),
#     ("Integrate Aerial Device", "The system shall include an unmanned aerial system.", "To monitor environments and infrastructure."),
#     ("Include Camera System", "The situational awareness component shall include a camera system.", "To capture essential visual data."),
#     ("Integrate Situational Platform", "The situational awareness component shall have an integrated platform.", "To provide a cohesive data framework."),
#     ("Power Through Kit", "The situational awareness system shall be powered through the kit.", "Ensures system autonomy."),
#     ("Existing Awareness Tech", "The situational awareness system shall leverage existing technology.", "To optimize existing capabilities."),
#     ("Communications Levels", "The communications sub-system shall operate on various levels (local, national, regional, international).", "Ensures broad communication capacity."),
#     ("Low-Bandwidth Communications", "The communication device shall transmit data over a low-bandwidth network.", "To optimize communication in variable conditions."),
#     ("Transmit Situation Reports", "The system shall enable transmitting situation reports.", "To keep authorities and aid personnel informed."),
#     ("Integrate Communications", "The communications system shall integrate with the situational awareness component.", "For streamlined operations."),
#     ("Power Communications", "The communications system shall be powered through the kit.", "For consistent operation and autonomy."),
#     ("Leverage Existing Communication Tech", "The communications sub-system shall leverage existing technology.", "To maintain efficiency and practicality."),
#     ("Resilience Against Natural Disasters", "The system shall be resilient against natural disaster conditions.", "Ensures reliable functionality under stress."),
#     ("Rapid Deployment", "The system shall be capable of rapid deployment.", "To ensure timely delivery of services."),
#     ("Modular Components", "The system shall include modular components for easy replacement or upgrade.", "To maintain and extend service life of the system."),
#     ("Secure Communications", "The system shall provide secure voice and data communications.", "To ensure confidentiality and integrity of information."),
#     ("Localized Training Programs", "The system shall include programs for localized training.", "Ensures applicable skills in diverse deployment regions."),
#     ("Autonomous Operation Capability", "The system shall have capabilities for semi-autonomous operation.", "Reduces operator demand in high-stress situations."),
#     ("Scalable Design", "The system shall have a scalable design to fit varied operational needs.", "Allows flexible response sizing."),
#     ("Interoperability Standard Compliance", "The system shall comply with relevant interoperability standards.", "To ensure broad compatibility."),
#     ("Data Logging", "The system shall log operational data for post-operation analysis.", "Enhances review and optimization capacity."),
#     ("Low Environmental Impact", "The system shall have a low environmental impact.", "To promote sustainability."),
#     ("Critical Event Focus", "The system shall be focused on providing aid during critical events.", "Addresses specific operational needs during crises."),
#     ("Supply Chain Resilience", "The system shall have a resilient supply chain for critical components.", "Ensures availability and minimizes delays."),
#     ("Remote Control Capability", "The system shall include remote control capabilities for critical functions.", "Supports operations in hazardous environments."),
#     ("Time-Sensitive Information Delivery", "The system shall deliver time-sensitive information quickly.", "Provides timely data to responders and decision makers."),
#     ("Coordinate with Public Entities", "The system shall facilitate coordination with public entities.", "For an integrated public-private response."),
#     ("System Security", "The system shall include security measures to prevent unauthorized access.", "To protect system integrity."),
#     ("Portable Power Sources", "The system shall include portable power sources to support off-grid operations.", "Ensures continuous operation in remote locations."),
#     ("Redundancy for Critical Functions", "The system shall include redundancy for all critical functions.", "Ensures system reliability under duress."),
#     ("Weather Data Integration", "Situational awareness components shall integrate local weather data streams.", "Provides environmental context for operations."),
#     ("Public-Private Data Sharing", "The system shall enable data sharing between public and private sector entities.", "Enhances cooperation and resource use."),
#     ("Humanitarian Logistics", "The system shall support humanitarian logistics activities.", "Facilitates resource delivery and setup."),
#     ("Adapted Tech for Diverse Terrains", "The system shall adapt its technology for various terrains.", "To ensure wide applicability."),
#     ("High Throughput Data Capacity", "The communication system shall support high-throughput data transfer.", "Enables detailed image and video sharing."),
#     ("Self-Diagnosis and Alerts", "The system shall include self-diagnosis capabilities with alert systems.", "Promotes proactive maintenance."),
#     ("Advanced Water Sensors", "Water systems shall include advanced sensors for quality monitoring.", "Ensures safety and compliance."),
#     ("Power Management Interface", "The power system shall include a management interface for monitoring usage.", "For efficient resource allocation."),
#     ("Local Partner Training", "The system shall provide training to local partners on operational use.", "Enhances capacity building and sustainability."),
#     ("Wide Range Power Input", "The power system shall support a wide range of input voltages.", "To use in diverse regions."),
#     ("Synchronized Updates", "The system shall support synchronized updates for all components.", "To ensure consistent operation."),
#     ("Mesh Network Capability", "The communications system shall support mesh network capabilities for extended range.", "Enables adaptable connectivity."),
#     ("User Feedback System", "The system shall include a user feedback mechanism for performance monitoring.", "To enhance service refinement."),
#     ("GIS Integration", "Situational awareness tools shall integrate with Geographic Information Systems (GIS).", "To enhance mapping and tracking capabilities."),
#     ("Battery Backup", "The system shall include battery backup systems for essential functions.", "Ensures operation during outages."),
#     ("Mission-Customizable Kits", "The system shall allow for mission-specific customization of kits.", "Enhances operational flexibility."),
#     ("Collaboration with Local Authorities", "The system shall support collaboration with local authorities in affected areas.", "Ensures alignment with local needs."),
#     ("Carbon Footprint Monitoring", "The system shall monitor and report its carbon footprint.", "Supports environmental accountability."),
#     ("Digital Training Library", "The system shall include a digital library with training resources.", "Provides continuous learning opportunities."),
#     ("Public Information Broadcast", "The system's communications capability shall include a public information broadcast channel.", "Raises public awareness in crisis scenarios."),
#     ("Accessibility Features", "The system shall include features that ensure accessibility for all users.", "Promotes inclusivity."),
#     ("Remote Diagnostics", "The system shall include capabilities for remote diagnostics.", "Supports efficient troubleshooting and maintenance."),
#     ("Network Adaptive Protocols", "The communication system protocols shall adapt to varying network conditions.", "Ensures consistent performance."),
#     ("Interactive User Guide", "An interactive user guide shall be available through the system.", "Facilitates quick user adaptation."),
#     ("Scalable Supply Network", "The system setup shall support a scalable supply network for kit components.", "Ensures responsiveness to demand fluctuations."),
#     ("Standardized Connectors", "The system shall use standardized connectors for all components.", "To ensure interoperability and ease of maintenance."),
#     ("Light Optical Components", "Situational awareness systems shall use lightweight optical components.", "To ease transport and installation."),
#     ("Dynamic Resource Allocation", "The system shall dynamically allocate resources based on real-time demand.", "Enhances efficiency."),
#     ("Thermal Management", "The system shall include thermal management systems to prevent overheating.", "Ensures reliability under stress."),
#     ("Weather Forecast Alerts", "Situational awareness components shall issue alerts based on forecasted weather conditions.", "Prepares users for imminent conditions."),
#     ("Standard Battery Packs", "The system shall use standard battery packs interchangeable across components.", "Simplifies logistics and replacement."),
#     ("Evacuation Route Mapping", "The system shall assist in mapping evacuation routes in crisis zones.", "Supports safety and coordination."),
#     ("Language Adaptation", "The system interface shall support multiple languages.", "Accommodates diverse operation zones."),
#     ("Cybersecurity Measures", "The system shall include robust cybersecurity measures.", "To guard against digital threats."),
#     ("Public Access Points", "The system shall provide public access points for emergency communications.", "Enhances community outreach."),
#     ("Field Data Logging", "The system shall log data from field operations for later analysis.", "Improves strategic insights."),
#     ("Emergency Response Community Interface", "The system shall include an interface for emergency response community communications.", "Increases coordination efficacy."),
#     ("Multi-Band Communication Devices", "The communications system shall include multi-band devices for wider frequency usage.", "Ensures broad connectivity."),
#     ("Incident Report Generation", "The system shall generate incident reports based on operational data.", "Aids in post-event analysis."),
#     ("Structural Health Monitoring", "The system infrastructure shall include structural health monitoring.", "Enhances proactive repairs."),
#     ("Graphical Configuration Tools", "The system shall provide graphical tools for configuration and management.", "Simplifies control operations."),
#     ("Deployed System Protection", "The system shall include deployable protection measures against environmental threats.", "Preserves system integrity in adverse conditions."),
# ]
# **Token Usage Info:**
#
# Tokens used: prompt=44367, completion=2372, total=46739
# [
#     ("Use COTS Technology", "The system shall utilize commercial-off-the-shelf technology.", "Requires limited development and accessible technology."),
#     ("Easy Operation", "The system shall be easy to operate.", "To allow various personnel to manage the system."),
#     ("Low Maintenance", "The system shall require low maintenance.", "To reduce operational sustainment costs."),
#     ("Export Capability", "The system shall be exportable to foreign nations.", "For deployment in various geographic regions."),
#     ("Non-Proprietary Technology", "The system shall use non-proprietary technology.", "To ensure flexibility and interoperability."),
#     ("Lightweight Design", "The system shall be lightweight and man-portable.", "For easy transport and deployment by personnel."),
#     ("Durability", "The system shall be durable and weather resistant.", "To withstand diverse environmental conditions."),
#     ("Limited HAZMAT Needs", "The system shall have limited HAZMAT requirements.", "To reduce risks associated with hazardous materials."),
#     ("Transportable System", "The system shall be transportable by air, sea, and land modes.", "To ensure flexible logistics."),
#     ("Cargo Pallet Fit", "The system components shall fit on a single 463L cargo air pallet.", "Standardizes military air transport."),
#     ("Produce Potable Water", "The water purification equipment shall produce potable water.", "To meet health and hygiene needs."),
#     ("Filtration System Inclusion", "The water system shall include a filtration system.", "Ensures the removal of contaminants."),
#     ("Water Distribution Capability", "The system shall include water distribution capability.", "To facilitate potable water supply."),
#     ("Include Storage Container", "The water system shall include a storage container.", "To store the purified water."),
#     ("Kit Power Source", "The water equipment shall be powered through the kit power generation system.", "To ensure energy efficiency."),
#     ("Leverage Existing Water Tech", "The water system shall leverage existing technology.", "To reduce development time and cost."),
#     ("Renewable Power Source", "The power sub-system shall primarily run on renewable sources.", "To promote sustainability and autonomy."),
#     ("Fossil Fuel Backup", "The power system shall have a fossil fuel generator backup.", "Ensures continuous operation."),
#     ("Support Kit Components", "The power system shall have sufficient capacity to support all kit components.", "Enables integrated operation."),
#     ("Use Existing Power Tech", "The power system shall leverage existing technology.", "To minimize resource use."),
#     ("Situational Awareness Features", "The system shall include local situational awareness capabilities.", "To provide essential data to responders."),
#     ("Integrate Aerial Device", "The system shall include an unmanned aerial system.", "To monitor environments and infrastructure."),
#     ("Include Camera System", "The situational awareness component shall include a camera system.", "To capture essential visual data."),
#     ("Integrate Situational Platform", "The situational awareness component shall have an integrated platform.", "To provide a cohesive data framework."),
#     ("Power Through Kit", "The situational awareness system shall be powered through the kit.", "Ensures system autonomy."),
#     ("Existing Awareness Tech", "The situational awareness system shall leverage existing technology.", "To optimize existing capabilities."),
#     ("Communications Levels", "The communications sub-system shall operate on various levels (local, national, regional, international).", "Ensures broad communication capacity."),
#     ("Low-Bandwidth Communications", "The communication device shall transmit data over a low-bandwidth network.", "To optimize communication in variable conditions."),
#     ("Transmit Situation Reports", "The system shall enable transmitting situation reports.", "To keep authorities and aid personnel informed."),
#     ("Integrate Communications", "The communications system shall integrate with the situational awareness component.", "For streamlined operations."),
#     ("Power Communications", "The communications system shall be powered through the kit.", "For consistent operation and autonomy."),
#     ("Leverage Existing Communication Tech", "The communications sub-system shall leverage existing technology.", "To maintain efficiency and practicality."),
#     ("Resilience Against Natural Disasters", "The system shall be resilient against natural disaster conditions.", "Ensures reliable functionality under stress."),
#     ("Rapid Deployment", "The system shall be capable of rapid deployment.", "To ensure timely delivery of services."),
#     ("Modular Components", "The system shall include modular components for easy replacement or upgrade.", "To maintain and extend service life of the system."),
#     ("Secure Communications", "The system shall provide secure voice and data communications.", "To ensure confidentiality and integrity of information."),
#     ("Localized Training Programs", "The system shall include programs for localized training.", "Ensures applicable skills in diverse deployment regions."),
#     ("Autonomous Operation Capability", "The system shall have capabilities for semi-autonomous operation.", "Reduces operator demand in high-stress situations."),
#     ("Scalable Design", "The system shall have a scalable design to fit varied operational needs.", "Allows flexible response sizing."),
#     ("Interoperability Standard Compliance", "The system shall comply with relevant interoperability standards.", "To ensure broad compatibility."),
#     ("Data Logging", "The system shall log operational data for post-operation analysis.", "Enhances review and optimization capacity."),
#     ("Low Environmental Impact", "The system shall have a low environmental impact.", "To promote sustainability."),
#     ("Critical Event Focus", "The system shall be focused on providing aid during critical events.", "Addresses specific operational needs during crises."),
#     ("Supply Chain Resilience", "The system shall have a resilient supply chain for critical components.", "Ensures availability and minimizes delays."),
#     ("Remote Control Capability", "The system shall include remote control capabilities for critical functions.", "Supports operations in hazardous environments."),
#     ("Time-Sensitive Information Delivery", "The system shall deliver time-sensitive information quickly.", "Provides timely data to responders and decision makers."),
#     ("Coordinate with Public Entities", "The system shall facilitate coordination with public entities.", "For an integrated public-private response."),
#     ("System Security", "The system shall include security measures to prevent unauthorized access.", "To protect system integrity."),
#     ("Portable Power Sources", "The system shall include portable power sources to support off-grid operations.", "Ensures continuous operation in remote locations."),
#     ("Redundancy for Critical Functions", "The system shall include redundancy for all critical functions.", "Ensures system reliability under duress."),
#     ("Weather Data Integration", "Situational awareness components shall integrate local weather data streams.", "Provides environmental context for operations."),
#     ("Public-Private Data Sharing", "The system shall enable data sharing between public and private sector entities.", "Enhances cooperation and resource use."),
#     ("Humanitarian Logistics", "The system shall support humanitarian logistics activities.", "Facilitates resource delivery and setup."),
#     ("Adapted Tech for Diverse Terrains", "The system shall adapt its technology for various terrains.", "To ensure wide applicability."),
#     ("High Throughput Data Capacity", "The communication system shall support high-throughput data transfer.", "Enables detailed image and video sharing."),
#     ("Self-Diagnosis and Alerts", "The system shall include self-diagnosis capabilities with alert systems.", "Promotes proactive maintenance."),
#     ("Advanced Water Sensors", "Water systems shall include advanced sensors for quality monitoring.", "Ensures safety and compliance."),
#     ("Power Management Interface", "The power system shall include a management interface for monitoring usage.", "For efficient resource allocation."),
#     ("Local Partner Training", "The system shall provide training to local partners on operational use.", "Enhances capacity building and sustainability."),
#     ("Wide Range Power Input", "The power system shall support a wide range of input voltages.", "To use in diverse regions."),
#     ("Synchronized Updates", "The system shall support synchronized updates for all components.", "To ensure consistent operation."),
#     ("Mesh Network Capability", "The communications system shall support mesh network capabilities for extended range.", "Enables adaptable connectivity."),
#     ("User Feedback System", "The system shall include a user feedback mechanism for performance monitoring.", "To enhance service refinement."),
#     ("GIS Integration", "Situational awareness tools shall integrate with Geographic Information Systems (GIS).", "To enhance mapping and tracking capabilities."),
#     ("Battery Backup", "The system shall include battery backup systems for essential functions.", "Ensures operation during outages."),
#     ("Mission-Customizable Kits", "The system shall allow for mission-specific customization of kits.", "Enhances operational flexibility."),
#     ("Collaboration with Local Authorities", "The system shall support collaboration with local authorities in affected areas.", "Ensures alignment with local needs."),
#     ("Carbon Footprint Monitoring", "The system shall monitor and report its carbon footprint.", "Supports environmental accountability."),
#     ("Digital Training Library", "The system shall include a digital library with training resources.", "Provides continuous learning opportunities."),
#     ("Public Information Broadcast", "The system's communications capability shall include a public information broadcast channel.", "Raises public awareness in crisis scenarios."),
#     ("Accessibility Features", "The system shall include features that ensure accessibility for all users.", "Promotes inclusivity."),
#     ("Remote Diagnostics", "The system shall include capabilities for remote diagnostics.", "Supports efficient troubleshooting and maintenance."),
#     ("Network Adaptive Protocols", "The communication system protocols shall adapt to varying network conditions.", "Ensures consistent performance."),
#     ("Interactive User Guide", "An interactive user guide shall be available through the system.", "Facilitates quick user adaptation."),
#     ("Scalable Supply Network", "The system setup shall support a scalable supply network for kit components.", "Ensures responsiveness to demand fluctuations."),
#     ("Standardized Connectors", "The system shall use standardized connectors for all components.", "To ensure interoperability and ease of maintenance."),
#     ("Light Optical Components", "Situational awareness systems shall use lightweight optical components.", "To ease transport and installation."),
#     ("Dynamic Resource Allocation", "The system shall dynamically allocate resources based on real-time demand.", "Enhances efficiency."),
#     ("Thermal Management", "The system shall include thermal management systems to prevent overheating.", "Ensures reliability under stress."),
#     ("Weather Forecast Alerts", "Situational awareness components shall issue alerts based on forecasted weather conditions.", "Prepares users for imminent conditions."),
#     ("Standard Battery Packs", "The system shall use standard battery packs interchangeable across components.", "Simplifies logistics and replacement."),
#     ("Evacuation Route Mapping", "The system shall assist in mapping evacuation routes in crisis zones.", "Supports safety and coordination."),
#     ("Language Adaptation", "The system interface shall support multiple languages.", "Accommodates diverse operation zones."),
#     ("Cybersecurity Measures", "The system shall include robust cybersecurity measures.", "To guard against digital threats."),
#     ("Public Access Points", "The system shall provide public access points for emergency communications.", "Enhances community outreach."),
#     ("Field Data Logging", "The system shall log data from field operations for later analysis.", "Improves strategic insights."),
#     ("Emergency Response Community Interface", "The system shall include an interface for emergency response community communications.", "Increases coordination efficacy."),
#     ("Multi-Band Communication Devices", "The communications system shall include multi-band devices for wider frequency usage.", "Ensures broad connectivity."),
#     ("Incident Report Generation", "The system shall generate incident reports based on operational data.", "Aids in post-event analysis."),
#     ("Structural Health Monitoring", "The system infrastructure shall include structural health monitoring.", "Enhances proactive repairs."),
#     ("Graphical Configuration Tools", "The system shall provide graphical tools for configuration and management.", "Simplifies control operations."),
#     ("Deployed System Protection", "The system shall include deployable protection measures against environmental threats.", "Preserves system integrity in adverse conditions."),
# ]
#
# ### Use COTS Technology
# - **Requirement:** The system shall utilize commercial-off-the-shelf technology.
# - **Rationale:** Requires limited development and accessible technology.
#
# ### Easy Operation
# - **Requirement:** The system shall be easy to operate.
# - **Rationale:** To allow various personnel to manage the system.
#
# ### Low Maintenance
# - **Requirement:** The system shall require low maintenance.
# - **Rationale:** To reduce operational sustainment costs.
#
# ### Export Capability
# - **Requirement:** The system shall be exportable to foreign nations.
# - **Rationale:** For deployment in various geographic regions.
#
# ### Non-Proprietary Technology
# - **Requirement:** The system shall use non-proprietary technology.
# - **Rationale:** To ensure flexibility and interoperability.
#
# ### Lightweight Design
# - **Requirement:** The system shall be lightweight and man-portable.
# - **Rationale:** For easy transport and deployment by personnel.
#
# ### Durability
# - **Requirement:** The system shall be durable and weather resistant.
# - **Rationale:** To withstand diverse environmental conditions.
#
# ### Limited HAZMAT Needs
# - **Requirement:** The system shall have limited HAZMAT requirements.
# - **Rationale:** To reduce risks associated with hazardous materials.
#
# ### Transportable System
# - **Requirement:** The system shall be transportable by air, sea, and land modes.
# - **Rationale:** To ensure flexible logistics.
#
# ### Cargo Pallet Fit
# - **Requirement:** The system components shall fit on a single 463L cargo air pallet.
# - **Rationale:** Standardizes military air transport.
#
# ### Produce Potable Water
# - **Requirement:** The water purification equipment shall produce potable water.
# - **Rationale:** To meet health and hygiene needs.
#
# ### Filtration System Inclusion
# - **Requirement:** The water system shall include a filtration system.
# - **Rationale:** Ensures the removal of contaminants.
#
# ### Water Distribution Capability
# - **Requirement:** The system shall include water distribution capability.
# - **Rationale:** To facilitate potable water supply.
#
# ### Include Storage Container
# - **Requirement:** The water system shall include a storage container.
# - **Rationale:** To store the purified water.
#
# ### Kit Power Source
# - **Requirement:** The water equipment shall be powered through the kit power generation system.
# - **Rationale:** To ensure energy efficiency.
#
# ### Leverage Existing Water Tech
# - **Requirement:** The water system shall leverage existing technology.
# - **Rationale:** To reduce development time and cost.
#
# ### Renewable Power Source
# - **Requirement:** The power sub-system shall primarily run on renewable sources.
# - **Rationale:** To promote sustainability and autonomy.
#
# ### Fossil Fuel Backup
# - **Requirement:** The power system shall have a fossil fuel generator backup.
# - **Rationale:** Ensures continuous operation.
#
# ### Support Kit Components
# - **Requirement:** The power system shall have sufficient capacity to support all kit components.
# - **Rationale:** Enables integrated operation.
#
# ### Use Existing Power Tech
# - **Requirement:** The power system shall leverage existing technology.
# - **Rationale:** To minimize resource use.
#
# ### Situational Awareness Features
# - **Requirement:** The system shall include local situational awareness capabilities.
# - **Rationale:** To provide essential data to responders.
#
# ### Integrate Aerial Device
# - **Requirement:** The system shall include an unmanned aerial system.
# - **Rationale:** To monitor environments and infrastructure.
#
# ### Include Camera System
# - **Requirement:** The situational awareness component shall include a camera system.
# - **Rationale:** To capture essential visual data.
#
# ### Integrate Situational Platform
# - **Requirement:** The situational awareness component shall have an integrated platform.
# - **Rationale:** To provide a cohesive data framework.
#
# ### Power Through Kit
# - **Requirement:** The situational awareness system shall be powered through the kit.
# - **Rationale:** Ensures system autonomy.
#
# ### Existing Awareness Tech
# - **Requirement:** The situational awareness system shall leverage existing technology.
# - **Rationale:** To optimize existing capabilities.
#
# ### Communications Levels
# - **Requirement:** The communications sub-system shall operate on various levels (local, national, regional, international).
# - **Rationale:** Ensures broad communication capacity.
#
# ### Low-Bandwidth Communications
# - **Requirement:** The communication device shall transmit data over a low-bandwidth network.
# - **Rationale:** To optimize communication in variable conditions.
#
# ### Transmit Situation Reports
# - **Requirement:** The system shall enable transmitting situation reports.
# - **Rationale:** To keep authorities and aid personnel informed.
#
# ### Integrate Communications
# - **Requirement:** The communications system shall integrate with the situational awareness component.
# - **Rationale:** For streamlined operations.
#
# ### Power Communications
# - **Requirement:** The communications system shall be powered through the kit.
# - **Rationale:** For consistent operation and autonomy.
#
# ### Leverage Existing Communication Tech
# - **Requirement:** The communications sub-system shall leverage existing technology.
# - **Rationale:** To maintain efficiency and practicality.
#
# ### Resilience Against Natural Disasters
# - **Requirement:** The system shall be resilient against natural disaster conditions.
# - **Rationale:** Ensures reliable functionality under stress.
#
# ### Rapid Deployment
# - **Requirement:** The system shall be capable of rapid deployment.
# - **Rationale:** To ensure timely delivery of services.
#
# ### Modular Components
# - **Requirement:** The system shall include modular components for easy replacement or upgrade.
# - **Rationale:** To maintain and extend service life of the system.
#
# ### Secure Communications
# - **Requirement:** The system shall provide secure voice and data communications.
# - **Rationale:** To ensure confidentiality and integrity of information.
#
# ### Localized Training Programs
# - **Requirement:** The system shall include programs for localized training.
# - **Rationale:** Ensures applicable skills in diverse deployment regions.
#
# ### Autonomous Operation Capability
# - **Requirement:** The system shall have capabilities for semi-autonomous operation.
# - **Rationale:** Reduces operator demand in high-stress situations.
#
# ### Scalable Design
# - **Requirement:** The system shall have a scalable design to fit varied operational needs.
# - **Rationale:** Allows flexible response sizing.
#
# ### Interoperability Standard Compliance
# - **Requirement:** The system shall comply with relevant interoperability standards.
# - **Rationale:** To ensure broad compatibility.
#
# ### Data Logging
# - **Requirement:** The system shall log operational data for post-operation analysis.
# - **Rationale:** Enhances review and optimization capacity.
#
# ### Low Environmental Impact
# - **Requirement:** The system shall have a low environmental impact.
# - **Rationale:** To promote sustainability.
#
# ### Critical Event Focus
# - **Requirement:** The system shall be focused on providing aid during critical events.
# - **Rationale:** Addresses specific operational needs during crises.
#
# ### Supply Chain Resilience
# - **Requirement:** The system shall have a resilient supply chain for critical components.
# - **Rationale:** Ensures availability and minimizes delays.
#
# ### Remote Control Capability
# - **Requirement:** The system shall include remote control capabilities for critical functions.
# - **Rationale:** Supports operations in hazardous environments.
#
# ### Time-Sensitive Information Delivery
# - **Requirement:** The system shall deliver time-sensitive information quickly.
# - **Rationale:** Provides timely data to responders and decision makers.
#
# ### Coordinate with Public Entities
# - **Requirement:** The system shall facilitate coordination with public entities.
# - **Rationale:** For an integrated public-private response.
#
# ### System Security
# - **Requirement:** The system shall include security measures to prevent unauthorized access.
# - **Rationale:** To protect system integrity.
#
# ### Portable Power Sources
# - **Requirement:** The system shall include portable power sources to support off-grid operations.
# - **Rationale:** Ensures continuous operation in remote locations.
#
# ### Redundancy for Critical Functions
# - **Requirement:** The system shall include redundancy for all critical functions.
# - **Rationale:** Ensures system reliability under duress.
#
# ### Weather Data Integration
# - **Requirement:** Situational awareness components shall integrate local weather data streams.
# - **Rationale:** Provides environmental context for operations.
#
# ### Public-Private Data Sharing
# - **Requirement:** The system shall enable data sharing between public and private sector entities.
# - **Rationale:** Enhances cooperation and resource use.
#
# ### Humanitarian Logistics
# - **Requirement:** The system shall support humanitarian logistics activities.
# - **Rationale:** Facilitates resource delivery and setup.
#
# ### Adapted Tech for Diverse Terrains
# - **Requirement:** The system shall adapt its technology for various terrains.
# - **Rationale:** To ensure wide applicability.
#
# ### High Throughput Data Capacity
# - **Requirement:** The communication system shall support high-throughput data transfer.
# - **Rationale:** Enables detailed image and video sharing.
#
# ### Self-Diagnosis and Alerts
# - **Requirement:** The system shall include self-diagnosis capabilities with alert systems.
# - **Rationale:** Promotes proactive maintenance.
#
# ### Advanced Water Sensors
# - **Requirement:** Water systems shall include advanced sensors for quality monitoring.
# - **Rationale:** Ensures safety and compliance.
#
# ### Power Management Interface
# - **Requirement:** The power system shall include a management interface for monitoring usage.
# - **Rationale:** For efficient resource allocation.
#
# ### Local Partner Training
# - **Requirement:** The system shall provide training to local partners on operational use.
# - **Rationale:** Enhances capacity building and sustainability.
#
# ### Wide Range Power Input
# - **Requirement:** The power system shall support a wide range of input voltages.
# - **Rationale:** To use in diverse regions.
#
# ### Synchronized Updates
# - **Requirement:** The system shall support synchronized updates for all components.
# - **Rationale:** To ensure consistent operation.
#
# ### Mesh Network Capability
# - **Requirement:** The communications system shall support mesh network capabilities for extended range.
# - **Rationale:** Enables adaptable connectivity.
#
# ### User Feedback System
# - **Requirement:** The system shall include a user feedback mechanism for performance monitoring.
# - **Rationale:** To enhance service refinement.
#
# ### GIS Integration
# - **Requirement:** Situational awareness tools shall integrate with Geographic Information Systems (GIS).
# - **Rationale:** To enhance mapping and tracking capabilities.
#
# ### Battery Backup
# - **Requirement:** The system shall include battery backup systems for essential functions.
# - **Rationale:** Ensures operation during outages.
#
# ### Mission-Customizable Kits
# - **Requirement:** The system shall allow for mission-specific customization of kits.
# - **Rationale:** Enhances operational flexibility.
#
# ### Collaboration with Local Authorities
# - **Requirement:** The system shall support collaboration with local authorities in affected areas.
# - **Rationale:** Ensures alignment with local needs.
#
# ### Carbon Footprint Monitoring
# - **Requirement:** The system shall monitor and report its carbon footprint.
# - **Rationale:** Supports environmental accountability.
#
# ### Digital Training Library
# - **Requirement:** The system shall include a digital library with training resources.
# - **Rationale:** Provides continuous learning opportunities.
#
# ### Public Information Broadcast
# - **Requirement:** The system's communications capability shall include a public information broadcast channel.
# - **Rationale:** Raises public awareness in crisis scenarios.
#
# ### Accessibility Features
# - **Requirement:** The system shall include features that ensure accessibility for all users.
# - **Rationale:** Promotes inclusivity.
#
# ### Remote Diagnostics
# - **Requirement:** The system shall include capabilities for remote diagnostics.
# - **Rationale:** Supports efficient troubleshooting and maintenance.
#
# ### Network Adaptive Protocols
# - **Requirement:** The communication system protocols shall adapt to varying network conditions.
# - **Rationale:** Ensures consistent performance.
#
# ### Interactive User Guide
# - **Requirement:** An interactive user guide shall be available through the system.
# - **Rationale:** Facilitates quick user adaptation.
#
# ### Scalable Supply Network
# - **Requirement:** The system setup shall support a scalable supply network for kit components.
# - **Rationale:** Ensures responsiveness to demand fluctuations.
#
# ### Standardized Connectors
# - **Requirement:** The system shall use standardized connectors for all components.
# - **Rationale:** To ensure interoperability and ease of maintenance.
#
# ### Light Optical Components
# - **Requirement:** Situational awareness systems shall use lightweight optical components.
# - **Rationale:** To ease transport and installation.
#
# ### Dynamic Resource Allocation
# - **Requirement:** The system shall dynamically allocate resources based on real-time demand.
# - **Rationale:** Enhances efficiency.
#
# ### Thermal Management
# - **Requirement:** The system shall include thermal management systems to prevent overheating.
# - **Rationale:** Ensures reliability under stress.
#
# ### Weather Forecast Alerts
# - **Requirement:** Situational awareness components shall issue alerts based on forecasted weather conditions.
# - **Rationale:** Prepares users for imminent conditions.
#
# ### Standard Battery Packs
# - **Requirement:** The system shall use standard battery packs interchangeable across components.
# - **Rationale:** Simplifies logistics and replacement.
#
# ### Evacuation Route Mapping
# - **Requirement:** The system shall assist in mapping evacuation routes in crisis zones.
# - **Rationale:** Supports safety and coordination.
#
# ### Language Adaptation
# - **Requirement:** The system interface shall support multiple languages.
# - **Rationale:** Accommodates diverse operation zones.
#
# ### Cybersecurity Measures
# - **Requirement:** The system shall include robust cybersecurity measures.
# - **Rationale:** To guard against digital threats.
#
# ### Public Access Points
# - **Requirement:** The system shall provide public access points for emergency communications.
# - **Rationale:** Enhances community outreach.
#
# ### Field Data Logging
# - **Requirement:** The system shall log data from field operations for later analysis.
# - **Rationale:** Improves strategic insights.
#
# ### Emergency Response Community Interface
# - **Requirement:** The system shall include an interface for emergency response community communications.
# - **Rationale:** Increases coordination efficacy.
#
# ### Multi-Band Communication Devices
# - **Requirement:** The communications system shall include multi-band devices for wider frequency usage.
# - **Rationale:** Ensures broad connectivity.
#
# ### Incident Report Generation
# - **Requirement:** The system shall generate incident reports based on operational data.
# - **Rationale:** Aids in post-event analysis.
#
# ### Structural Health Monitoring
# - **Requirement:** The system infrastructure shall include structural health monitoring.
# - **Rationale:** Enhances proactive repairs.
#
# ### Graphical Configuration Tools
# - **Requirement:** The system shall provide graphical tools for configuration and management.
# - **Rationale:** Simplifies control operations.
#
# ### Deployed System Protection
# - **Requirement:** The system shall include deployable protection measures against environmental threats.
# - **Rationale:** Preserves system integrity in adverse conditions.

# %%
# Out:
# OpenAI API Key retrieved successfully.
# ✅ File `PEAK System.docx` added to messages for analysis.
# **Your prompt:**
# Generate a set of 2 user requirements.
# - Each requirment should yaml format.
# - The name shall be five or fewer words introducing the requirement.
# - The text shall be in the format of a shall statement, that is clear and concise and include a rationale should explain the source behind numeric requirement.
# - Output ONLY yaml.
# - No explanation, no extra text, just the yaml.
# **ChatGPT Response:**
#
# ```yaml
# - name: Utilization of Commercial Technology
#   text: The system shall utilize commercial-off-the-shelf technology with limited development to meet the need for a deployable, easily operable, and maintainable solution during time-sensitive events. This reduces development time and cost by leveraging existing products.
#
# - name: Water Production Capacity
#   text: The water purification equipment shall produce potable water from fresh, brackish, or salt water, powered through the kit power generation system. Rationale: Provides clean drinking water and hygiene solutions during crises, leveraging existing technology for efficiency.
# **Token Usage Info:**
#
# Tokens used: prompt=44336, completion=118, total=44454
# ```yaml
# - name: Utilization of Commercial Technology
#   text: The system shall utilize commercial-off-the-shelf technology with limited development to meet the need for a deployable, easily operable, and maintainable solution during time-sensitive events. This reduces development time and cost by leveraging existing products.
#
# - name: Water Production Capacity
#   text: The water purification equipment shall produce potable water from fresh, brackish, or salt water, powered through the kit power generation system. Rationale: Provides clean drinking water and hygiene solutions during crises, leveraging existing technology for efficiency.

# %%
# Navigate to System Analysis phase

import io

import capellambse
from capellambse import decl
sa = model.sa
print(sa)

model_update = f"""
- parent: !uuid {sa.uuid}
  extend:
    requirement_modules:
      - name: User Requirements
        promise_id: moduleid
"""
# the below line applies the model_update to the model
decl.apply(model, io.StringIO(model_update));
print("after",sa)
# Out:
# <SystemAnalysis 'System Analysis' (1469af64-4214-4be5-913c-cadbfd4fcd5b)>
# .actor_exchanges = []
# .all_actors = ... # omitted
# .all_capabilities = ... # omitted
# .all_capability_exploitations = ... # omitted
# .all_classes = ... # omitted
# .all_collections = ... # omitted
# .all_complex_values = ... # omitted
# .all_component_exchanges = ... # omitted
# .all_components = ... # omitted
# .all_enumerations = ... # omitted
# .all_function_exchanges = ... # omitted
# .all_functional_chains = ... # omitted
# .all_functions = ... # omitted
# .all_interfaces = ... # omitted
# .all_missions = ... # omitted
# .all_module_types = ... # omitted
# .all_relation_types = ... # omitted
# .all_requirement_types = ... # omitted
# .all_requirements = ... # omitted
# .all_unions = ... # omitted
# .applied_property_value_groups = []
# .applied_property_values = []
# .capability_package = <CapabilityPkg 'Capabilities' (dac23fee-5d63-4d22-9a4c-e2155cc6c1ba)>
# .component_exchange_categories = []
# .component_exchanges = []
# .component_package = <SystemComponentPkg 'Structure' (8c746338-5eec-4cbe-88b3-5695a2ab0d92)>
# .constraints = []
# .data_package = <DataPkg 'Data' (74cb9d37-22cc-463c-84fd-1b9987dfac14)>
# .description = Markup('')
# .diagrams = [0] <Diagram '[MCB] PEAK  Capabilities and involved Actors and Entities'>
#             [1] <Diagram '[MCB]  PEAK  Capabilities and involved Actors and Entities - Peak Sub-Capabilities'>
#             [2] <Diagram '[SAB] Crisis Response Coordination'>
#             [3] <Diagram '[SAB] Emergenct Response Service Delivery'>
#             [4] <Diagram '[SAB] Power QAS'>
#             [5] <Diagram '[SAB] Situational Awareness'>
#             [6] <Diagram '[SAB] Water Generation QAS'>
#             [7] <Diagram '[SAB] Water Power SA Comms'>
#             [8] <Diagram '[SAB] Power QAS (activities)'>
#             [9] <Diagram '[SAB] Structure'>
# .extensions = []
# .filtering_criteria = []
# .function_package = <SystemFunctionPkg 'System Functions' (94d47345-3cf0-4376-b2c4-525fb03b445e)>
# .interface_package = <InterfacePkg 'Interfaces' (988a0ebb-e7f3-4343-be1f-565ad3a7bf41)>
# .mission_package = <MissionPkg 'Missions' (6552bfcf-bc57-46d3-b2ab-dda8f6b7294a)>
# .name = 'System Analysis'
# .parent = <SystemEngineering 'PEAK' (69642134-a5ae-4fc3-9ad9-cdde615e7396)>
# .progress_status = 'NOT_SET'
# .property_value_groups = []
# .property_value_packages = [0] <PropertyValuePkg 'Requirements' (c1f9e487-0691-4e61-8c57-f621f133c1a1)>
# .property_values = []
# .pvmt = <Property Value Management for <SystemAnalysis 'System Analysis' (1469af64-4214-4be5-913c-cadbfd4fcd5b)>>
# .requirement_modules = []
# .requirement_types_folders = []
# .requirements = []
# .root_component = <SystemComponent 'PEAK' (ddc7faf6-4ef7-4adb-9c7b-8a55f0958947)>
# .root_function = <SystemFunction 'Root System Function' (336ac50f-81a4-4709-9529-7293cdb84b09)>
# .sid = ''
# .summary = ''
# .traces = []
# .uuid = '1469af64-4214-4be5-913c-cadbfd4fcd5b'
# .validation = <capellambse.extensions.validation._validate.LayerValidation object at 0x7f0f7f075dd0>
# .visible_on_diagrams = []
# .xtype = 'org.polarsys.capella.core.data.ctx:SystemAnalysis'
# after <SystemAnalysis 'System Analysis' (1469af64-4214-4be5-913c-cadbfd4fcd5b)>
# .actor_exchanges = []
# .all_actors = ... # omitted
# .all_capabilities = ... # omitted
# .all_capability_exploitations = ... # omitted
# .all_classes = ... # omitted
# .all_collections = ... # omitted
# .all_complex_values = ... # omitted
# .all_component_exchanges = ... # omitted
# .all_components = ... # omitted
# .all_enumerations = ... # omitted
# .all_function_exchanges = ... # omitted
# .all_functional_chains = ... # omitted
# .all_functions = ... # omitted
# .all_interfaces = ... # omitted
# .all_missions = ... # omitted
# .all_module_types = ... # omitted
# .all_relation_types = ... # omitted
# .all_requirement_types = ... # omitted
# .all_requirements = ... # omitted
# .all_unions = ... # omitted
# .applied_property_value_groups = []
# .applied_property_values = []
# .capability_package = <CapabilityPkg 'Capabilities' (dac23fee-5d63-4d22-9a4c-e2155cc6c1ba)>
# .component_exchange_categories = []
# .component_exchanges = []
# .component_package = <SystemComponentPkg 'Structure' (8c746338-5eec-4cbe-88b3-5695a2ab0d92)>
# .constraints = []
# .data_package = <DataPkg 'Data' (74cb9d37-22cc-463c-84fd-1b9987dfac14)>
# .description = Markup('')
# .diagrams = [0] <Diagram '[MCB] PEAK  Capabilities and involved Actors and Entities'>
#             [1] <Diagram '[MCB]  PEAK  Capabilities and involved Actors and Entities - Peak Sub-Capabilities'>
#             [2] <Diagram '[SAB] Crisis Response Coordination'>
#             [3] <Diagram '[SAB] Emergenct Response Service Delivery'>
#             [4] <Diagram '[SAB] Power QAS'>
#             [5] <Diagram '[SAB] Situational Awareness'>
#             [6] <Diagram '[SAB] Water Generation QAS'>
#             [7] <Diagram '[SAB] Water Power SA Comms'>
#             [8] <Diagram '[SAB] Power QAS (activities)'>
#             [9] <Diagram '[SAB] Structure'>
# .extensions = [0] <CapellaModule 'User Requirements' (90645741-3a11-48f2-88a5-c846013b7ae9)>
# .filtering_criteria = []
# .function_package = <SystemFunctionPkg 'System Functions' (94d47345-3cf0-4376-b2c4-525fb03b445e)>
# .interface_package = <InterfacePkg 'Interfaces' (988a0ebb-e7f3-4343-be1f-565ad3a7bf41)>
# .mission_package = <MissionPkg 'Missions' (6552bfcf-bc57-46d3-b2ab-dda8f6b7294a)>
# .name = 'System Analysis'
# .parent = <SystemEngineering 'PEAK' (69642134-a5ae-4fc3-9ad9-cdde615e7396)>
# .progress_status = 'NOT_SET'
# .property_value_groups = []
# .property_value_packages = [0] <PropertyValuePkg 'Requirements' (c1f9e487-0691-4e61-8c57-f621f133c1a1)>
# .property_values = []
# .pvmt = <Property Value Management for <SystemAnalysis 'System Analysis' (1469af64-4214-4be5-913c-cadbfd4fcd5b)>>
# .requirement_modules = [0] <CapellaModule 'User Requirements' (90645741-3a11-48f2-88a5-c846013b7ae9)>
# .requirement_types_folders = []
# .requirements = []
# .root_component = <SystemComponent 'PEAK' (ddc7faf6-4ef7-4adb-9c7b-8a55f0958947)>
# .root_function = <SystemFunction 'Root System Function' (336ac50f-81a4-4709-9529-7293cdb84b09)>
# .sid = ''
# .summary = ''
# .traces = []
# .uuid = '1469af64-4214-4be5-913c-cadbfd4fcd5b'
# .validation = <capellambse.extensions.validation._validate.LayerValidation object at 0x7f0f7e317310>
# .visible_on_diagrams = []
# .xtype = 'org.polarsys.capella.core.data.ctx:SystemAnalysis'

# %%
# Navigate to System Analysis phase

import io

import capellambse
from capellambse import decl
sa = model.sa
print(sa.requirement_modules[0])
import yaml

yaml_structure = [   
        {
            "name": name,
            "text": description+ " Rationale:" +rationale   ,
        }
        for name, description, rationale in requirements
        
]

# Dump YAML to string
yaml_string = yaml.dump(yaml_structure, sort_keys=False, allow_unicode=True)


print(yaml_string)
def indent_yaml_block(yaml_string, indent=6):
    prefix = " " * indent
    return "\n".join(prefix + line if line.strip() else line for line in yaml_string.splitlines())

indented_block = indent_yaml_block(yaml_string, indent=6)

model_update = f"""
- parent: !uuid {sa.requirement_modules[0].uuid}
  extend:
    requirements:
{indented_block}
"""
print(model_update)



# the below line applies the model_update to the model
decl.apply(model, io.StringIO(model_update));

print("after",sa.requirement_modules[0])
# Out:
# <CapellaModule 'User Requirements' (90645741-3a11-48f2-88a5-c846013b7ae9)>
# .applied_property_value_groups = []
# .applied_property_values = []
# .attributes = []
# .constraints = []
# .description = ''
# .diagrams = []
# .extensions = []
# .filtering_criteria = []
# .folders = []
# .identifier = ''
# .layer = <SystemAnalysis 'System Analysis' (1469af64-4214-4be5-913c-cadbfd4fcd5b)>
# .long_name = ''
# .name = 'User Requirements'
# .parent = <SystemAnalysis 'System Analysis' (1469af64-4214-4be5-913c-cadbfd4fcd5b)>
# .prefix = ''
# .progress_status = 'NOT_SET'
# .property_value_groups = []
# .property_value_packages = []
# .property_values = []
# .pvmt = <Property Value Management for <CapellaModule 'User Requirements' (90645741-3a11-48f2-88a5-c846013b7ae9)>>
# .requirement_types_folders = []
# .requirements = []
# .sid = ''
# .summary = ''
# .traces = []
# .type = None
# .uuid = '90645741-3a11-48f2-88a5-c846013b7ae9'
# .validation = <capellambse.extensions.validation._validate.ElementValidation object at 0x7f0f7f08c350>
# .visible_on_diagrams = []
# .xtype = 'CapellaRequirements:CapellaModule'
# - name: Use COTS Technology
#   text: The system shall utilize commercial-off-the-shelf technology. Rationale:Requires
#     limited development and accessible technology.
# - name: Easy Operation
#   text: The system shall be easy to operate. Rationale:To allow various personnel
#     to manage the system.
# - name: Low Maintenance
#   text: The system shall require low maintenance. Rationale:To reduce operational
#     sustainment costs.
# - name: Export Capability
#   text: The system shall be exportable to foreign nations. Rationale:For deployment
#     in various geographic regions.
# - name: Non-Proprietary Technology
#   text: The system shall use non-proprietary technology. Rationale:To ensure flexibility
#     and interoperability.
# - name: Lightweight Design
#   text: The system shall be lightweight and man-portable. Rationale:For easy transport
#     and deployment by personnel.
# - name: Durability
#   text: The system shall be durable and weather resistant. Rationale:To withstand
#     diverse environmental conditions.
# - name: Limited HAZMAT Needs
#   text: The system shall have limited HAZMAT requirements. Rationale:To reduce risks
#     associated with hazardous materials.
# - name: Transportable System
#   text: The system shall be transportable by air, sea, and land modes. Rationale:To
#     ensure flexible logistics.
# - name: Cargo Pallet Fit
#   text: The system components shall fit on a single 463L cargo air pallet. Rationale:Standardizes
#     military air transport.
# - name: Produce Potable Water
#   text: The water purification equipment shall produce potable water. Rationale:To
#     meet health and hygiene needs.
# - name: Filtration System Inclusion
#   text: The water system shall include a filtration system. Rationale:Ensures the
#     removal of contaminants.
# - name: Water Distribution Capability
#   text: The system shall include water distribution capability. Rationale:To facilitate
#     potable water supply.
# - name: Include Storage Container
#   text: The water system shall include a storage container. Rationale:To store the
#     purified water.
# - name: Kit Power Source
#   text: The water equipment shall be powered through the kit power generation system.
#     Rationale:To ensure energy efficiency.
# - name: Leverage Existing Water Tech
#   text: The water system shall leverage existing technology. Rationale:To reduce development
#     time and cost.
# - name: Renewable Power Source
#   text: The power sub-system shall primarily run on renewable sources. Rationale:To
#     promote sustainability and autonomy.
# - name: Fossil Fuel Backup
#   text: The power system shall have a fossil fuel generator backup. Rationale:Ensures
#     continuous operation.
# - name: Support Kit Components
#   text: The power system shall have sufficient capacity to support all kit components.
#     Rationale:Enables integrated operation.
# - name: Use Existing Power Tech
#   text: The power system shall leverage existing technology. Rationale:To minimize
#     resource use.
# - name: Situational Awareness Features
#   text: The system shall include local situational awareness capabilities. Rationale:To
#     provide essential data to responders.
# - name: Integrate Aerial Device
#   text: The system shall include an unmanned aerial system. Rationale:To monitor environments
#     and infrastructure.
# - name: Include Camera System
#   text: The situational awareness component shall include a camera system. Rationale:To
#     capture essential visual data.
# - name: Integrate Situational Platform
#   text: The situational awareness component shall have an integrated platform. Rationale:To
#     provide a cohesive data framework.
# - name: Power Through Kit
#   text: The situational awareness system shall be powered through the kit. Rationale:Ensures
#     system autonomy.
# - name: Existing Awareness Tech
#   text: The situational awareness system shall leverage existing technology. Rationale:To
#     optimize existing capabilities.
# - name: Communications Levels
#   text: The communications sub-system shall operate on various levels (local, national,
#     regional, international). Rationale:Ensures broad communication capacity.
# - name: Low-Bandwidth Communications
#   text: The communication device shall transmit data over a low-bandwidth network.
#     Rationale:To optimize communication in variable conditions.
# - name: Transmit Situation Reports
#   text: The system shall enable transmitting situation reports. Rationale:To keep
#     authorities and aid personnel informed.
# - name: Integrate Communications
#   text: The communications system shall integrate with the situational awareness component.
#     Rationale:For streamlined operations.
# - name: Power Communications
#   text: The communications system shall be powered through the kit. Rationale:For
#     consistent operation and autonomy.
# - name: Leverage Existing Communication Tech
#   text: The communications sub-system shall leverage existing technology. Rationale:To
#     maintain efficiency and practicality.
# - name: Resilience Against Natural Disasters
#   text: The system shall be resilient against natural disaster conditions. Rationale:Ensures
#     reliable functionality under stress.
# - name: Rapid Deployment
#   text: The system shall be capable of rapid deployment. Rationale:To ensure timely
#     delivery of services.
# - name: Modular Components
#   text: The system shall include modular components for easy replacement or upgrade.
#     Rationale:To maintain and extend service life of the system.
# - name: Secure Communications
#   text: The system shall provide secure voice and data communications. Rationale:To
#     ensure confidentiality and integrity of information.
# - name: Localized Training Programs
#   text: The system shall include programs for localized training. Rationale:Ensures
#     applicable skills in diverse deployment regions.
# - name: Autonomous Operation Capability
#   text: The system shall have capabilities for semi-autonomous operation. Rationale:Reduces
#     operator demand in high-stress situations.
# - name: Scalable Design
#   text: The system shall have a scalable design to fit varied operational needs. Rationale:Allows
#     flexible response sizing.
# - name: Interoperability Standard Compliance
#   text: The system shall comply with relevant interoperability standards. Rationale:To
#     ensure broad compatibility.
# - name: Data Logging
#   text: The system shall log operational data for post-operation analysis. Rationale:Enhances
#     review and optimization capacity.
# - name: Low Environmental Impact
#   text: The system shall have a low environmental impact. Rationale:To promote sustainability.
# - name: Critical Event Focus
#   text: The system shall be focused on providing aid during critical events. Rationale:Addresses
#     specific operational needs during crises.
# - name: Supply Chain Resilience
#   text: The system shall have a resilient supply chain for critical components. Rationale:Ensures
#     availability and minimizes delays.
# - name: Remote Control Capability
#   text: The system shall include remote control capabilities for critical functions.
#     Rationale:Supports operations in hazardous environments.
# - name: Time-Sensitive Information Delivery
#   text: The system shall deliver time-sensitive information quickly. Rationale:Provides
#     timely data to responders and decision makers.
# - name: Coordinate with Public Entities
#   text: The system shall facilitate coordination with public entities. Rationale:For
#     an integrated public-private response.
# - name: System Security
#   text: The system shall include security measures to prevent unauthorized access.
#     Rationale:To protect system integrity.
# - name: Portable Power Sources
#   text: The system shall include portable power sources to support off-grid operations.
#     Rationale:Ensures continuous operation in remote locations.
# - name: Redundancy for Critical Functions
#   text: The system shall include redundancy for all critical functions. Rationale:Ensures
#     system reliability under duress.
# - name: Weather Data Integration
#   text: Situational awareness components shall integrate local weather data streams.
#     Rationale:Provides environmental context for operations.
# - name: Public-Private Data Sharing
#   text: The system shall enable data sharing between public and private sector entities.
#     Rationale:Enhances cooperation and resource use.
# - name: Humanitarian Logistics
#   text: The system shall support humanitarian logistics activities. Rationale:Facilitates
#     resource delivery and setup.
# - name: Adapted Tech for Diverse Terrains
#   text: The system shall adapt its technology for various terrains. Rationale:To ensure
#     wide applicability.
# - name: High Throughput Data Capacity
#   text: The communication system shall support high-throughput data transfer. Rationale:Enables
#     detailed image and video sharing.
# - name: Self-Diagnosis and Alerts
#   text: The system shall include self-diagnosis capabilities with alert systems. Rationale:Promotes
#     proactive maintenance.
# - name: Advanced Water Sensors
#   text: Water systems shall include advanced sensors for quality monitoring. Rationale:Ensures
#     safety and compliance.
# - name: Power Management Interface
#   text: The power system shall include a management interface for monitoring usage.
#     Rationale:For efficient resource allocation.
# - name: Local Partner Training
#   text: The system shall provide training to local partners on operational use. Rationale:Enhances
#     capacity building and sustainability.
# - name: Wide Range Power Input
#   text: The power system shall support a wide range of input voltages. Rationale:To
#     use in diverse regions.
# - name: Synchronized Updates
#   text: The system shall support synchronized updates for all components. Rationale:To
#     ensure consistent operation.
# - name: Mesh Network Capability
#   text: The communications system shall support mesh network capabilities for extended
#     range. Rationale:Enables adaptable connectivity.
# - name: User Feedback System
#   text: The system shall include a user feedback mechanism for performance monitoring.
#     Rationale:To enhance service refinement.
# - name: GIS Integration
#   text: Situational awareness tools shall integrate with Geographic Information Systems
#     (GIS). Rationale:To enhance mapping and tracking capabilities.
# - name: Battery Backup
#   text: The system shall include battery backup systems for essential functions. Rationale:Ensures
#     operation during outages.
# - name: Mission-Customizable Kits
#   text: The system shall allow for mission-specific customization of kits. Rationale:Enhances
#     operational flexibility.
# - name: Collaboration with Local Authorities
#   text: The system shall support collaboration with local authorities in affected
#     areas. Rationale:Ensures alignment with local needs.
# - name: Carbon Footprint Monitoring
#   text: The system shall monitor and report its carbon footprint. Rationale:Supports
#     environmental accountability.
# - name: Digital Training Library
#   text: The system shall include a digital library with training resources. Rationale:Provides
#     continuous learning opportunities.
# - name: Public Information Broadcast
#   text: The system's communications capability shall include a public information
#     broadcast channel. Rationale:Raises public awareness in crisis scenarios.
# - name: Accessibility Features
#   text: The system shall include features that ensure accessibility for all users.
#     Rationale:Promotes inclusivity.
# - name: Remote Diagnostics
#   text: The system shall include capabilities for remote diagnostics. Rationale:Supports
#     efficient troubleshooting and maintenance.
# - name: Network Adaptive Protocols
#   text: The communication system protocols shall adapt to varying network conditions.
#     Rationale:Ensures consistent performance.
# - name: Interactive User Guide
#   text: An interactive user guide shall be available through the system. Rationale:Facilitates
#     quick user adaptation.
# - name: Scalable Supply Network
#   text: The system setup shall support a scalable supply network for kit components.
#     Rationale:Ensures responsiveness to demand fluctuations.
# - name: Standardized Connectors
#   text: The system shall use standardized connectors for all components. Rationale:To
#     ensure interoperability and ease of maintenance.
# - name: Light Optical Components
#   text: Situational awareness systems shall use lightweight optical components. Rationale:To
#     ease transport and installation.
# - name: Dynamic Resource Allocation
#   text: The system shall dynamically allocate resources based on real-time demand.
#     Rationale:Enhances efficiency.
# - name: Thermal Management
#   text: The system shall include thermal management systems to prevent overheating.
#     Rationale:Ensures reliability under stress.
# - name: Weather Forecast Alerts
#   text: Situational awareness components shall issue alerts based on forecasted weather
#     conditions. Rationale:Prepares users for imminent conditions.
# - name: Standard Battery Packs
#   text: The system shall use standard battery packs interchangeable across components.
#     Rationale:Simplifies logistics and replacement.
# - name: Evacuation Route Mapping
#   text: The system shall assist in mapping evacuation routes in crisis zones. Rationale:Supports
#     safety and coordination.
# - name: Language Adaptation
#   text: The system interface shall support multiple languages. Rationale:Accommodates
#     diverse operation zones.
# - name: Cybersecurity Measures
#   text: The system shall include robust cybersecurity measures. Rationale:To guard
#     against digital threats.
# - name: Public Access Points
#   text: The system shall provide public access points for emergency communications.
#     Rationale:Enhances community outreach.
# - name: Field Data Logging
#   text: The system shall log data from field operations for later analysis. Rationale:Improves
#     strategic insights.
# - name: Emergency Response Community Interface
#   text: The system shall include an interface for emergency response community communications.
#     Rationale:Increases coordination efficacy.
# - name: Multi-Band Communication Devices
#   text: The communications system shall include multi-band devices for wider frequency
#     usage. Rationale:Ensures broad connectivity.
# - name: Incident Report Generation
#   text: The system shall generate incident reports based on operational data. Rationale:Aids
#     in post-event analysis.
# - name: Structural Health Monitoring
#   text: The system infrastructure shall include structural health monitoring. Rationale:Enhances
#     proactive repairs.
# - name: Graphical Configuration Tools
#   text: The system shall provide graphical tools for configuration and management.
#     Rationale:Simplifies control operations.
# - name: Deployed System Protection
#   text: The system shall include deployable protection measures against environmental
#     threats. Rationale:Preserves system integrity in adverse conditions.
#
#
# - parent: !uuid 90645741-3a11-48f2-88a5-c846013b7ae9
#   extend:
#     requirements:
#       - name: Use COTS Technology
#         text: The system shall utilize commercial-off-the-shelf technology. Rationale:Requires
#           limited development and accessible technology.
#       - name: Easy Operation
#         text: The system shall be easy to operate. Rationale:To allow various personnel
#           to manage the system.
#       - name: Low Maintenance
#         text: The system shall require low maintenance. Rationale:To reduce operational
#           sustainment costs.
#       - name: Export Capability
#         text: The system shall be exportable to foreign nations. Rationale:For deployment
#           in various geographic regions.
#       - name: Non-Proprietary Technology
#         text: The system shall use non-proprietary technology. Rationale:To ensure flexibility
#           and interoperability.
#       - name: Lightweight Design
#         text: The system shall be lightweight and man-portable. Rationale:For easy transport
#           and deployment by personnel.
#       - name: Durability
#         text: The system shall be durable and weather resistant. Rationale:To withstand
#           diverse environmental conditions.
#       - name: Limited HAZMAT Needs
#         text: The system shall have limited HAZMAT requirements. Rationale:To reduce risks
#           associated with hazardous materials.
#       - name: Transportable System
#         text: The system shall be transportable by air, sea, and land modes. Rationale:To
#           ensure flexible logistics.
#       - name: Cargo Pallet Fit
#         text: The system components shall fit on a single 463L cargo air pallet. Rationale:Standardizes
#           military air transport.
#       - name: Produce Potable Water
#         text: The water purification equipment shall produce potable water. Rationale:To
#           meet health and hygiene needs.
#       - name: Filtration System Inclusion
#         text: The water system shall include a filtration system. Rationale:Ensures the
#           removal of contaminants.
#       - name: Water Distribution Capability
#         text: The system shall include water distribution capability. Rationale:To facilitate
#           potable water supply.
#       - name: Include Storage Container
#         text: The water system shall include a storage container. Rationale:To store the
#           purified water.
#       - name: Kit Power Source
#         text: The water equipment shall be powered through the kit power generation system.
#           Rationale:To ensure energy efficiency.
#       - name: Leverage Existing Water Tech
#         text: The water system shall leverage existing technology. Rationale:To reduce development
#           time and cost.
#       - name: Renewable Power Source
#         text: The power sub-system shall primarily run on renewable sources. Rationale:To
#           promote sustainability and autonomy.
#       - name: Fossil Fuel Backup
#         text: The power system shall have a fossil fuel generator backup. Rationale:Ensures
#           continuous operation.
#       - name: Support Kit Components
#         text: The power system shall have sufficient capacity to support all kit components.
#           Rationale:Enables integrated operation.
#       - name: Use Existing Power Tech
#         text: The power system shall leverage existing technology. Rationale:To minimize
#           resource use.
#       - name: Situational Awareness Features
#         text: The system shall include local situational awareness capabilities. Rationale:To
#           provide essential data to responders.
#       - name: Integrate Aerial Device
#         text: The system shall include an unmanned aerial system. Rationale:To monitor environments
#           and infrastructure.
#       - name: Include Camera System
#         text: The situational awareness component shall include a camera system. Rationale:To
#           capture essential visual data.
#       - name: Integrate Situational Platform
#         text: The situational awareness component shall have an integrated platform. Rationale:To
#           provide a cohesive data framework.
#       - name: Power Through Kit
#         text: The situational awareness system shall be powered through the kit. Rationale:Ensures
#           system autonomy.
#       - name: Existing Awareness Tech
#         text: The situational awareness system shall leverage existing technology. Rationale:To
#           optimize existing capabilities.
#       - name: Communications Levels
#         text: The communications sub-system shall operate on various levels (local, national,
#           regional, international). Rationale:Ensures broad communication capacity.
#       - name: Low-Bandwidth Communications
#         text: The communication device shall transmit data over a low-bandwidth network.
#           Rationale:To optimize communication in variable conditions.
#       - name: Transmit Situation Reports
#         text: The system shall enable transmitting situation reports. Rationale:To keep
#           authorities and aid personnel informed.
#       - name: Integrate Communications
#         text: The communications system shall integrate with the situational awareness component.
#           Rationale:For streamlined operations.
#       - name: Power Communications
#         text: The communications system shall be powered through the kit. Rationale:For
#           consistent operation and autonomy.
#       - name: Leverage Existing Communication Tech
#         text: The communications sub-system shall leverage existing technology. Rationale:To
#           maintain efficiency and practicality.
#       - name: Resilience Against Natural Disasters
#         text: The system shall be resilient against natural disaster conditions. Rationale:Ensures
#           reliable functionality under stress.
#       - name: Rapid Deployment
#         text: The system shall be capable of rapid deployment. Rationale:To ensure timely
#           delivery of services.
#       - name: Modular Components
#         text: The system shall include modular components for easy replacement or upgrade.
#           Rationale:To maintain and extend service life of the system.
#       - name: Secure Communications
#         text: The system shall provide secure voice and data communications. Rationale:To
#           ensure confidentiality and integrity of information.
#       - name: Localized Training Programs
#         text: The system shall include programs for localized training. Rationale:Ensures
#           applicable skills in diverse deployment regions.
#       - name: Autonomous Operation Capability
#         text: The system shall have capabilities for semi-autonomous operation. Rationale:Reduces
#           operator demand in high-stress situations.
#       - name: Scalable Design
#         text: The system shall have a scalable design to fit varied operational needs. Rationale:Allows
#           flexible response sizing.
#       - name: Interoperability Standard Compliance
#         text: The system shall comply with relevant interoperability standards. Rationale:To
#           ensure broad compatibility.
#       - name: Data Logging
#         text: The system shall log operational data for post-operation analysis. Rationale:Enhances
#           review and optimization capacity.
#       - name: Low Environmental Impact
#         text: The system shall have a low environmental impact. Rationale:To promote sustainability.
#       - name: Critical Event Focus
#         text: The system shall be focused on providing aid during critical events. Rationale:Addresses
#           specific operational needs during crises.
#       - name: Supply Chain Resilience
#         text: The system shall have a resilient supply chain for critical components. Rationale:Ensures
#           availability and minimizes delays.
#       - name: Remote Control Capability
#         text: The system shall include remote control capabilities for critical functions.
#           Rationale:Supports operations in hazardous environments.
#       - name: Time-Sensitive Information Delivery
#         text: The system shall deliver time-sensitive information quickly. Rationale:Provides
#           timely data to responders and decision makers.
#       - name: Coordinate with Public Entities
#         text: The system shall facilitate coordination with public entities. Rationale:For
#           an integrated public-private response.
#       - name: System Security
#         text: The system shall include security measures to prevent unauthorized access.
#           Rationale:To protect system integrity.
#       - name: Portable Power Sources
#         text: The system shall include portable power sources to support off-grid operations.
#           Rationale:Ensures continuous operation in remote locations.
#       - name: Redundancy for Critical Functions
#         text: The system shall include redundancy for all critical functions. Rationale:Ensures
#           system reliability under duress.
#       - name: Weather Data Integration
#         text: Situational awareness components shall integrate local weather data streams.
#           Rationale:Provides environmental context for operations.
#       - name: Public-Private Data Sharing
#         text: The system shall enable data sharing between public and private sector entities.
#           Rationale:Enhances cooperation and resource use.
#       - name: Humanitarian Logistics
#         text: The system shall support humanitarian logistics activities. Rationale:Facilitates
#           resource delivery and setup.
#       - name: Adapted Tech for Diverse Terrains
#         text: The system shall adapt its technology for various terrains. Rationale:To ensure
#           wide applicability.
#       - name: High Throughput Data Capacity
#         text: The communication system shall support high-throughput data transfer. Rationale:Enables
#           detailed image and video sharing.
#       - name: Self-Diagnosis and Alerts
#         text: The system shall include self-diagnosis capabilities with alert systems. Rationale:Promotes
#           proactive maintenance.
#       - name: Advanced Water Sensors
#         text: Water systems shall include advanced sensors for quality monitoring. Rationale:Ensures
#           safety and compliance.
#       - name: Power Management Interface
#         text: The power system shall include a management interface for monitoring usage.
#           Rationale:For efficient resource allocation.
#       - name: Local Partner Training
#         text: The system shall provide training to local partners on operational use. Rationale:Enhances
#           capacity building and sustainability.
#       - name: Wide Range Power Input
#         text: The power system shall support a wide range of input voltages. Rationale:To
#           use in diverse regions.
#       - name: Synchronized Updates
#         text: The system shall support synchronized updates for all components. Rationale:To
#           ensure consistent operation.
#       - name: Mesh Network Capability
#         text: The communications system shall support mesh network capabilities for extended
#           range. Rationale:Enables adaptable connectivity.
#       - name: User Feedback System
#         text: The system shall include a user feedback mechanism for performance monitoring.
#           Rationale:To enhance service refinement.
#       - name: GIS Integration
#         text: Situational awareness tools shall integrate with Geographic Information Systems
#           (GIS). Rationale:To enhance mapping and tracking capabilities.
#       - name: Battery Backup
#         text: The system shall include battery backup systems for essential functions. Rationale:Ensures
#           operation during outages.
#       - name: Mission-Customizable Kits
#         text: The system shall allow for mission-specific customization of kits. Rationale:Enhances
#           operational flexibility.
#       - name: Collaboration with Local Authorities
#         text: The system shall support collaboration with local authorities in affected
#           areas. Rationale:Ensures alignment with local needs.
#       - name: Carbon Footprint Monitoring
#         text: The system shall monitor and report its carbon footprint. Rationale:Supports
#           environmental accountability.
#       - name: Digital Training Library
#         text: The system shall include a digital library with training resources. Rationale:Provides
#           continuous learning opportunities.
#       - name: Public Information Broadcast
#         text: The system's communications capability shall include a public information
#           broadcast channel. Rationale:Raises public awareness in crisis scenarios.
#       - name: Accessibility Features
#         text: The system shall include features that ensure accessibility for all users.
#           Rationale:Promotes inclusivity.
#       - name: Remote Diagnostics
#         text: The system shall include capabilities for remote diagnostics. Rationale:Supports
#           efficient troubleshooting and maintenance.
#       - name: Network Adaptive Protocols
#         text: The communication system protocols shall adapt to varying network conditions.
#           Rationale:Ensures consistent performance.
#       - name: Interactive User Guide
#         text: An interactive user guide shall be available through the system. Rationale:Facilitates
#           quick user adaptation.
#       - name: Scalable Supply Network
#         text: The system setup shall support a scalable supply network for kit components.
#           Rationale:Ensures responsiveness to demand fluctuations.
#       - name: Standardized Connectors
#         text: The system shall use standardized connectors for all components. Rationale:To
#           ensure interoperability and ease of maintenance.
#       - name: Light Optical Components
#         text: Situational awareness systems shall use lightweight optical components. Rationale:To
#           ease transport and installation.
#       - name: Dynamic Resource Allocation
#         text: The system shall dynamically allocate resources based on real-time demand.
#           Rationale:Enhances efficiency.
#       - name: Thermal Management
#         text: The system shall include thermal management systems to prevent overheating.
#           Rationale:Ensures reliability under stress.
#       - name: Weather Forecast Alerts
#         text: Situational awareness components shall issue alerts based on forecasted weather
#           conditions. Rationale:Prepares users for imminent conditions.
#       - name: Standard Battery Packs
#         text: The system shall use standard battery packs interchangeable across components.
#           Rationale:Simplifies logistics and replacement.
#       - name: Evacuation Route Mapping
#         text: The system shall assist in mapping evacuation routes in crisis zones. Rationale:Supports
#           safety and coordination.
#       - name: Language Adaptation
#         text: The system interface shall support multiple languages. Rationale:Accommodates
#           diverse operation zones.
#       - name: Cybersecurity Measures
#         text: The system shall include robust cybersecurity measures. Rationale:To guard
#           against digital threats.
#       - name: Public Access Points
#         text: The system shall provide public access points for emergency communications.
#           Rationale:Enhances community outreach.
#       - name: Field Data Logging
#         text: The system shall log data from field operations for later analysis. Rationale:Improves
#           strategic insights.
#       - name: Emergency Response Community Interface
#         text: The system shall include an interface for emergency response community communications.
#           Rationale:Increases coordination efficacy.
#       - name: Multi-Band Communication Devices
#         text: The communications system shall include multi-band devices for wider frequency
#           usage. Rationale:Ensures broad connectivity.
#       - name: Incident Report Generation
#         text: The system shall generate incident reports based on operational data. Rationale:Aids
#           in post-event analysis.
#       - name: Structural Health Monitoring
#         text: The system infrastructure shall include structural health monitoring. Rationale:Enhances
#           proactive repairs.
#       - name: Graphical Configuration Tools
#         text: The system shall provide graphical tools for configuration and management.
#           Rationale:Simplifies control operations.
#       - name: Deployed System Protection
#         text: The system shall include deployable protection measures against environmental
#           threats. Rationale:Preserves system integrity in adverse conditions.
#
# after <CapellaModule 'User Requirements' (90645741-3a11-48f2-88a5-c846013b7ae9)>
# .applied_property_value_groups = []
# .applied_property_values = []
# .attributes = []
# .constraints = []
# .description = ''
# .diagrams = []
# .extensions = []
# .filtering_criteria = []
# .folders = []
# .identifier = ''
# .layer = <SystemAnalysis 'System Analysis' (1469af64-4214-4be5-913c-cadbfd4fcd5b)>
# .long_name = ''
# .name = 'User Requirements'
# .parent = <SystemAnalysis 'System Analysis' (1469af64-4214-4be5-913c-cadbfd4fcd5b)>
# .prefix = ''
# .progress_status = 'NOT_SET'
# .property_value_groups = []
# .property_value_packages = []
# .property_values = []
# .pvmt = <Property Value Management for <CapellaModule 'User Requirements' (90645741-3a11-48f2-88a5-c846013b7ae9)>>
# .requirement_types_folders = []
# .requirements = [0] <Requirement 'Use COTS Technology' (f048abf8-026b-427e-bab8-a5b807f53220)>
#                 [1] <Requirement 'Easy Operation' (727cda0b-9fc7-409a-bbf1-0cabae756b92)>
#                 [2] <Requirement 'Low Maintenance' (c073a16c-7a7c-4417-84a7-3bc86afc54f5)>
#                 [3] <Requirement 'Export Capability' (fd3da4fa-0815-4b65-bbc0-f5ddab20c8c4)>
#                 [4] <Requirement 'Non-Proprietary Technology' (03b356b5-7b86-419a-bf4c-00e5e323e7da)>
#                 [5] <Requirement 'Lightweight Design' (e5d434b3-c43a-4f79-8148-d2c085f9d265)>
#                 [6] <Requirement 'Durability' (a55d41b8-0218-4629-992c-aad4706f14d4)>
#                 [7] <Requirement 'Limited HAZMAT Needs' (7ee5b285-3ad8-407b-a1af-540cb9045cda)>
#                 [8] <Requirement 'Transportable System' (61e43109-2c0b-4b5d-a820-1ab76f1f4e2b)>
#                 [9] <Requirement 'Cargo Pallet Fit' (5bc632c1-af32-4682-945d-607c3dfe6912)>
#                 [10] <Requirement 'Produce Potable Water' (53773e29-a148-481e-aada-47987c2a1357)>
#                 [11] <Requirement 'Filtration System Inclusion' (1b408a6b-ea13-4c87-888a-d1f276c265e4)>
#                 [12] <Requirement 'Water Distribution Capability' (e034047e-3d6c-4cd3-bfa4-a5e89e7613bf)>
#                 [13] <Requirement 'Include Storage Container' (7546d353-e92f-4f5e-9fd2-0d4aef285e80)>
#                 [14] <Requirement 'Kit Power Source' (69bd77f0-61f8-4e76-8ee5-97357959b4cb)>
#                 [15] <Requirement 'Leverage Existing Water Tech' (9f01a3b9-4945-4cf9-9d29-4717ab2876d2)>
#                 [16] <Requirement 'Renewable Power Source' (b3aa5623-5095-4f76-a306-faf82a0e9cf3)>
#                 [17] <Requirement 'Fossil Fuel Backup' (4612aebc-795e-4315-8482-2680d4197315)>
#                 [18] <Requirement 'Support Kit Components' (db208455-2f1c-4bea-8277-7d0dfeb05740)>
#                 [19] <Requirement 'Use Existing Power Tech' (eb323dd1-0d54-4e13-8951-5ff2281c427b)>
#                 [20] <Requirement 'Situational Awareness Features' (2760202e-ef64-41f4-a9f9-e4a1f63f6bb7)>
#                 [21] <Requirement 'Integrate Aerial Device' (f80f9d03-f3a2-4690-974f-e0bf28470bc6)>
#                 [22] <Requirement 'Include Camera System' (ed52e4cf-63c1-4d12-906b-bf2b06423ac9)>
#                 [23] <Requirement 'Integrate Situational Platform' (d4e57853-9b16-4d61-8f0e-7740ec3de662)>
#                 [24] <Requirement 'Power Through Kit' (9596e2b6-002f-45e2-8244-3c6febf05979)>
#                 [25] <Requirement 'Existing Awareness Tech' (fafd2974-09a8-4d07-8189-415d57e5d32b)>
#                 [26] <Requirement 'Communications Levels' (dd640a56-2832-448a-87d2-e8dde2639126)>
#                 [27] <Requirement 'Low-Bandwidth Communications' (54646119-85af-4a04-8d40-ad28eed7b3e0)>
#                 [28] <Requirement 'Transmit Situation Reports' (0133d8c8-c011-473a-b1d9-810e9a9469d7)>
#                 [29] <Requirement 'Integrate Communications' (bfbe63f7-9593-4f45-903b-597bbaf5c9f7)>
#                 [30] <Requirement 'Power Communications' (5efb1749-742c-407a-896c-527d487df1c9)>
#                 [31] <Requirement 'Leverage Existing Communication Tech' (9f8e7489-7510-4a8d-a0f9-9b0294c17efc)>
#                 [32] <Requirement 'Resilience Against Natural Disasters' (7f60976c-7ba9-4f67-ba42-29dab5c40f61)>
#                 [33] <Requirement 'Rapid Deployment' (9d517a84-4466-423c-9761-335acdbab0e4)>
#                 [34] <Requirement 'Modular Components' (8fd556c3-7272-4286-9dc7-468cefd64a69)>
#                 [35] <Requirement 'Secure Communications' (2d525c10-bc76-4d13-b906-9e8cf8acc76e)>
#                 [36] <Requirement 'Localized Training Programs' (dc412dd7-1365-4a47-a063-9f325e3fd13e)>
#                 [37] <Requirement 'Autonomous Operation Capability' (34712745-fd0b-43ac-b6a2-152e8232355a)>
#                 [38] <Requirement 'Scalable Design' (a9e3d169-6a02-4131-b8ba-635570386f0c)>
#                 [39] <Requirement 'Interoperability Standard Compliance' (ec76c685-d6b2-4b68-a6f5-488266ed57bd)>
#                 [40] <Requirement 'Data Logging' (5ee1bcb0-10e1-4cf3-9be1-48124de00939)>
#                 [41] <Requirement 'Low Environmental Impact' (95f9c7c5-2dd7-47ca-bc61-18277ff400db)>
#                 [42] <Requirement 'Critical Event Focus' (3605c76c-2d0c-43c1-b094-9c9cb16f9dd9)>
#                 [43] <Requirement 'Supply Chain Resilience' (1a84ca74-3828-42c0-b9d9-f6f9af4613a2)>
#                 [44] <Requirement 'Remote Control Capability' (6fb2830b-8262-4e62-88a1-7842152a5a58)>
#                 [45] <Requirement 'Time-Sensitive Information Delivery' (6d5551b9-e1df-4e60-aa1d-0785b2874914)>
#                 [46] <Requirement 'Coordinate with Public Entities' (6e97c580-95a1-445c-8634-be2d75f7da65)>
#                 [47] <Requirement 'System Security' (a4e63e67-484a-46cb-ba84-1433bfa56f35)>
#                 [48] <Requirement 'Portable Power Sources' (ca02d49e-c407-4fdc-a1a0-89edf6b7bc33)>
#                 [49] <Requirement 'Redundancy for Critical Functions' (f8761ff2-2b56-4f56-b8d1-36f356f9a690)>
#                 [50] <Requirement 'Weather Data Integration' (1b600244-f724-494a-9c60-309d2c47b6e7)>
#                 [51] <Requirement 'Public-Private Data Sharing' (aa3a5b1f-eeea-4e7f-ac45-42b5bb4da098)>
#                 [52] <Requirement 'Humanitarian Logistics' (31b239ff-f9b0-4e83-99cc-033d998984e1)>
#                 [53] <Requirement 'Adapted Tech for Diverse Terrains' (477a3dad-47a6-4ecc-8bb7-92223b8a882f)>
#                 [54] <Requirement 'High Throughput Data Capacity' (54b5978c-10f3-410f-b32e-d1e599a7b0c6)>
#                 [55] <Requirement 'Self-Diagnosis and Alerts' (ce579235-615c-4713-88ff-d673bb10ec88)>
#                 [56] <Requirement 'Advanced Water Sensors' (188c4eed-b141-4bb9-9e33-a4e8a3cfa215)>
#                 [57] <Requirement 'Power Management Interface' (bd9a26d5-4158-42d5-9a21-38233e181f62)>
#                 [58] <Requirement 'Local Partner Training' (fdcb1d3b-6c0b-4428-acbd-d924b522a793)>
#                 [59] <Requirement 'Wide Range Power Input' (c9f1f3cf-185b-4016-a2dd-b2b71050b8ed)>
#                 [60] <Requirement 'Synchronized Updates' (7edf483a-089c-4f46-9470-8635a23bac0b)>
#                 [61] <Requirement 'Mesh Network Capability' (edb0c21f-3131-4f6b-8e2a-096a7e2881d6)>
#                 [62] <Requirement 'User Feedback System' (e3ce73d2-3f83-42b6-ab3e-d1bd684bb4dd)>
#                 [63] <Requirement 'GIS Integration' (f232c30a-4beb-46b4-85dc-1d8e87b8fab1)>
#                 [64] <Requirement 'Battery Backup' (f248b297-7f90-4cd3-a269-1c23fd4b7bc9)>
#                 [65] <Requirement 'Mission-Customizable Kits' (89f3d9b0-9fad-4e65-a7e3-d20f292e7804)>
#                 [66] <Requirement 'Collaboration with Local Authorities' (0fed052f-488f-49ff-b5bd-fe40cdbf5e2b)>
#                 [67] <Requirement 'Carbon Footprint Monitoring' (c2b7439a-b50e-4919-b379-c4ce18e9da2b)>
#                 [68] <Requirement 'Digital Training Library' (49070765-a9df-45b3-a1b6-2b42e3142841)>
#                 [69] <Requirement 'Public Information Broadcast' (124bbd4d-2926-4cc3-aad4-efe12005063f)>
#                 [70] <Requirement 'Accessibility Features' (cb40999a-7e40-4664-8bd8-b9c24b60d5a2)>
#                 [71] <Requirement 'Remote Diagnostics' (d4e8f139-0c08-410b-bbaf-94d2bf9a4b90)>
#                 [72] <Requirement 'Network Adaptive Protocols' (71bb9d1c-4b68-4f2c-9873-7e5ce068dd58)>
#                 [73] <Requirement 'Interactive User Guide' (0c5a32e9-2763-4f8f-a56c-7f1d2526a29d)>
#                 [74] <Requirement 'Scalable Supply Network' (b03c6c20-3dc4-416d-8a83-04b31351b16e)>
#                 [75] <Requirement 'Standardized Connectors' (b0795839-55fe-455d-9e48-3134c60f829c)>
#                 [76] <Requirement 'Light Optical Components' (792375fc-2c33-4c53-8961-243357daa35f)>
#                 [77] <Requirement 'Dynamic Resource Allocation' (b2856f14-99bb-4ed8-bfa5-3acd69257e8f)>
#                 [78] <Requirement 'Thermal Management' (87fac7c2-ca87-4f58-9705-a08fcecee58a)>
#                 [79] <Requirement 'Weather Forecast Alerts' (ee27c4d0-36ed-4778-98f2-d52dee9a276d)>
#                 [80] <Requirement 'Standard Battery Packs' (f553f0fa-12c7-48df-ae2f-731e5ed0aff2)>
#                 [81] <Requirement 'Evacuation Route Mapping' (53d4f59c-1042-4927-8c2c-ebe523a2bd64)>
#                 [82] <Requirement 'Language Adaptation' (49b9adb6-2c83-49c3-a642-71fa48062421)>
#                 [83] <Requirement 'Cybersecurity Measures' (3006aa58-ff96-45be-874b-5b9cdeb726e7)>
#                 [84] <Requirement 'Public Access Points' (53d9d87a-55a6-4f99-9a91-eb6e9db78c1f)>
#                 [85] <Requirement 'Field Data Logging' (1064aca2-0978-441a-ad09-cf50bf085ebd)>
#                 [86] <Requirement 'Emergency Response Community Interface' (5bc6cee0-0810-4a7a-9e1a-a4c842a1f16b)>
#                 [87] <Requirement 'Multi-Band Communication Devices' (02cf59d5-6b31-472a-aba0-66a22555b18a)>
#                 [88] <Requirement 'Incident Report Generation' (d298dd5c-da67-45f6-b730-878f51088f65)>
#                 [89] <Requirement 'Structural Health Monitoring' (abd0ce92-d913-41c2-ad68-6a5b5c012f85)>
#                 [90] <Requirement 'Graphical Configuration Tools' (cc8eb8d8-bf08-430c-a1b7-adeb21dd4dd4)>
#                 [91] <Requirement 'Deployed System Protection' (66e2da24-b359-4de3-a2d7-d47ffaae3f6b)>
# .sid = ''
# .summary = ''
# .traces = []
# .type = None
# .uuid = '90645741-3a11-48f2-88a5-c846013b7ae9'
# .validation = <capellambse.extensions.validation._validate.ElementValidation object at 0x7f0f7d6ca310>
# .visible_on_diagrams = []
# .xtype = 'CapellaRequirements:CapellaModule'

# %%
model.save()

# %%
import ast
#from capella_tools import Open_AI_RAG_manager
import Open_AI_RAG_manager
# Step 1: Get YAML content
yaml_content = yaml_handler.get_yaml_content()
analyzer = Open_AI_RAG_manager.ChatGPTAnalyzer(yaml_content)

analyzer.add_text_file_to_messages("PEAK System.docx")
prompt = """
Generate a set of 2 user requirements. 
- Each requirment should be created in SysML V2 format.
- The name shall be five or fewer words introducing the requirement.
- The body shall be in the format of a shall statement, that is clear and concise. 
- The rationale should explain the source behind numeric requirement. 
- Output ONLY SysML V2 textual syntax.
- No explanation, no extra text, just the list in SysML V2 textual syntax.
"""

analyzer.follow_up_prompt(prompt)
requirements_text = analyzer.get_response()
print(requirements_text)
# Out:
# OpenAI API Key retrieved successfully.
# ✅ File `PEAK System.docx` added to messages for analysis.
# **Your prompt:**
# Generate a set of 2 user requirements.
# - Each requirment should be created in SysML V2 format.
# - The name shall be five or fewer words introducing the requirement.
# - The body shall be in the format of a shall statement, that is clear and concise.
# - The rationale should explain the source behind numeric requirement.
# - Output ONLY SysML V2 textual syntax.
# - No explanation, no extra text, just the list in SysML V2 textual syntax.
# **ChatGPT Response:**
#
# ```
# requirement "Portable Power Generation" {
#     shall "The power sub-system shall generate power through renewable resources with a minimum capacity to support all kit components simultaneously."
#     rationale "The requirement for renewable resources aligns with environmental sustainability goals and is supported by the need for fossil fuel backup as outlined in the PEAK System document."
# }
#
# requirement "Communication Device Functionality" {
#     shall "The communication sub-system shall transmit and receive voice and data over a low-bandwidth network."
#     rationale "The requirement for low-bandwidth operation is due to potential limitations in remote areas, as described in the PEAK System document."
# }
# **Token Usage Info:**
#
# Tokens used: prompt=44355, completion=127, total=44482
# ```
# requirement "Portable Power Generation" {
#     shall "The power sub-system shall generate power through renewable resources with a minimum capacity to support all kit components simultaneously."
#     rationale "The requirement for renewable resources aligns with environmental sustainability goals and is supported by the need for fossil fuel backup as outlined in the PEAK System document."
# }
#
# requirement "Communication Device Functionality" {
#     shall "The communication sub-system shall transmit and receive voice and data over a low-bandwidth network."
#     rationale "The requirement for low-bandwidth operation is due to potential limitations in remote areas, as described in the PEAK System document."
# }

# %%
from capella_tools import Open_AI_RAG_manager
# Step 1: Get YAML content
yaml_content = yaml_handler.get_yaml_content()
analyzer = Open_AI_RAG_manager.ChatGPTAnalyzer(yaml_content)

analyzer.add_text_file_to_messages("PEAK System.docx")
prompt = """
Generate a set of 2 user requirements do not stop for brevity only stop when no unique requirements exist.
-Produce them in yaml format with the following attributes.
--Long Name: Use less than 5 words to decribe the requirement.
--Text: Use shall statemen that are clear concise and valid and include a rationale for the requirement.
--promise_uuid : put the phrase "promise_id"
"""

analyzer.follow_up_prompt(prompt)
chatgpt_response = analyzer.get_response()
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# OpenAI API Key retrieved successfully.
# ✅ File `PEAK System.docx` added to messages for analysis.
# **Your prompt:**
# Generate a set of 100 user requirements do not stop for brevity only stop when no unique requirements exist.
# -Produce them in the following format.
# ## Heading
# Requirement Body **Rationale:** Rationale text
# - Use less than 5 word heading
# - Produce requirement body that is a clear and concise shall statement.
# - Create rationale content for any performance related requirements.
# **ChatGPT Response:**
#
# ## Utilize Commercial Technology
# The system shall utilize commercial-off-the-shelf technology. **Rationale:** Leverages existing proven solutions.
#
# ## Easy Operation
# The system shall be easy to operate. **Rationale:** Ensures efficient deployment with minimal training.
#
# ## Easy Training
# The system shall be easy to train users. **Rationale:** Reduces time needed to prepare responders.
#
# ## Low Maintenance
# The system shall require low maintenance. **Rationale:** Reduces operational burden and costs.
#
# ## Low Sustainment Costs
# The system shall have low sustainment costs. **Rationale:** Ensures affordability for long-term use.
#
# ## Exportable Design
# The system shall be exportable to foreign nations. **Rationale:** Facilitates global deployment.
#
# ## Non-Proprietary Technology
# The system shall use non-proprietary technology. **Rationale:** Avoids vendor lock-in and supports integration.
#
# ## Lightweight Design
# The system shall be lightweight and man-portable. **Rationale:** Ease of transport and deployment.
#
# ## Durability
# The system shall be durable and weather-resistant. **Rationale:** Ensures reliability in various conditions.
#
# ## Limited HAZMAT
# The system shall have limited HAZMAT requirements. **Rationale:** Minimizes safety risks and compliance burdens.
#
# ## Multimodal Transport
# The system shall be transportable by air, sea, and land. **Rationale:** Enables rapid deployment in diverse environments.
#
# ## Cargo Pallet Fit
# The system shall fit on a single 463L cargo air pallet. **Rationale:** Standardizes transport logistics.
#
# ## Purify Potable Water
# The water equipment shall produce potable water from fresh, brackish, or salt water. **Rationale:** Ensures versatility in water sources to provide safe drinking water.
#
# ## Filtration System
# The water equipment shall include a filtration system. **Rationale:** Removes impurities to meet safety standards.
#
# ## Distribution Capability
# The water equipment shall include distribution capability. **Rationale:** Ensures access to purified water across locations.
#
# ## Storage Container
# The water equipment shall include a storage container. **Rationale:** Allows for water storage as needed.
#
# ## Drinking Water
# The system shall provide potable water for drinking. **Rationale:** Ensures water safety for consumption.
#
# ## Hygiene Water
# The system shall provide potable water for hygiene. **Rationale:** Supports health standards in crisis situations.
#
# ## Power Generation
# The water equipment shall be powered through the kit power generation system. **Rationale:** Ensures consistent operation using renewable energy.
#
# ## Renewable Sources
# The power subsystem shall run primarily on renewable sources. **Rationale:** Reduces environmental impact and dependency on fossil fuels.
#
# ## Fossil Fuel Backup
# The power subsystem shall include a fossil fuel generator backup. **Rationale:** Provides reliable power under low renewable resource conditions.
#
# ## Power Components
# The power subsystem shall provide power to all kit components simultaneously. **Rationale:** Ensures all systems are operational when needed.
#
# ## Existing Technology
# The power subsystem shall leverage existing technology. **Rationale:** Utilizes proven solutions for reliability.
#
# ## Time Sensitive Information
# The situational awareness component shall provide time-sensitive information quickly. **Rationale:** Supports rapid decision-making in critical situations.
#
# ## UAS Integration
# The system shall integrate an unmanned aerial system. **Rationale:** Enhances situational awareness with aerial views.
#
# ## Control Device
# The system shall include a control device for the UAS. **Rationale:** Offers manual operation and oversight of aerial equipment.
#
# ## Camera System
# The system shall include still and motion cameras. **Rationale:** Provides comprehensive environmental imagery.
#
# ## Integrated Platform
# The system shall include an integrated platform for data collection. **Rationale:** Enables data centralization and analysis.
#
# ## Energy Integration
# The situational awareness system shall be powered through the kit power generation system. **Rationale:** Ensures continuous operation without additional infrastructure.
#
# ## Low-Bandwidth Network
# The communication sub-system shall transmit over a low-bandwidth network. **Rationale:** Ensures operational capability where bandwidth is limited.
#
# ## Voice and Data
# The communication device shall transmit voice and data. **Rationale:** Supports comprehensive communication needs.
#
# ## Situation Reports
# The system shall enable communication of situation reports. **Rationale:** Facilitates clear updates and collaboration.
#
# ## International Communication
# The communication sub-system shall operate at international levels. **Rationale:** Supports cross-border collaboration and coordination.
#
# ## Situational Awareness Integration
# The communication sub-system shall integrate with the situational awareness component. **Rationale:** Enhances the sharing of observations and decisions.
#
# ## Energy Powered
# The communication sub-system shall be powered through the kit power generation system. **Rationale:** Ensures consistent communication capabilities.
#
# ## Partnership Collaboration
# The system shall facilitate partnership collaboration. **Rationale:** Enhances response capabilities through shared resources and efforts.
#
# ## Scalable Services
# The system shall enable scalable critical services. **Rationale:** Adapts to different crisis magnitudes.
#
# ## Weather Resistant
# The system shall be weather-resistant. **Rationale:** Operates under diverse environmental conditions.
#
# ## Efficient Training
# The system shall allow efficient user training. **Rationale:** Prepares responders swiftly to handle equipment.
#
# ## Minimal Development
# The system shall utilize technology with minimal development. **Rationale:** Reduces time to deploy by using ready technologies.
#
# ## Authorities Communication
# The system shall enable communication with authorities. **Rationale:** Ensures orders and updates flow efficiently during crises.
#
# I have listed 50 unique requirements based on the provided information. To create more user requirements from the available data, I would need additional information or distinct requirements not already covered. Please provide further details if another set of requirements are needed._Tokens used: prompt=44000, completion=1143, total=45143_
