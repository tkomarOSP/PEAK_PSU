# %% [markdown]
# Load the document and define the elements of QAS from the document.

# %%
from capella_tools import Open_AI_RAG_manager
# Step 1: Get YAML content

analyzer = Open_AI_RAG_manager.ChatGPTAnalyzer()

#analyzer.add_text_file_to_messages("PEAK System.docx")
prompt = """
Generate Quality Attribute Scenarios for the water management for each on the following. Avaliability, Modifiability, Performance, Security,Testability, Usability
Provide details of Quality Attribute Scenario: 
That includes
-A paragraph that capture the scenario as a user story.
-List the elements of the scenario:
--Source: The operarional user community
--Stimulus: Powering on the water purification system 
--Environment: Source of of non brackish water 
--Artifact - The PEAK system
--Artifact State - The current state is off.
--Response: System producing water.
--Response Measure: Propose property value and its units.
--Requirement Reference: Any requirement souce attached and general knowledge. 
"""

analyzer.follow_up_prompt(prompt)
chatgpt_response = analyzer.get_response()
# Out:
# ✅ ChatGPTAnalyzer initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: Default
# 🤖 Model: gpt-4o
# **Your prompt:**
# Generate Quality Attribute Scenarios for the water management for each on the following. Avaliability, Modifiability, Performance, Security,Testability, Usability
# Provide details of Quality Attribute Scenario:
# That includes
# -A paragraph that capture the scenario as a user story.
# -List the elements of the scenario:
# --Source: The operarional user community
# --Stimulus: Powering on the water purification system
# --Environment: Source of of non brackish water
# --Artifact - The PEAK system
# --Artifact State - The current state is off.
# --Response: System producing water.
# --Response Measure: Propose property value and its units.
# --Requirement Reference: Any requirement souce attached and general knowledge.
# **Response:**
#
# ### Availability
#
# **User Story:**
# ...
