# %% [markdown]
# # System Engineering Model Analyzer:
# ## Leveraging AI for System Engineering models

# %% [markdown]
# ### Model-Specific Code (Do Not Modify)
#
# This section contains code that is specific to the system model. It is updated only when the model is changed and should not require user modifications under normal circumstances.
#
# If a new model is introduced, ensure this section is reviewed and updated as needed.

# %%
#!pip install --upgrade git+https://github.com/tkSDISW/Capella_Tools 
import capellambse.decl

from capella_tools import capellambse_helper

from IPython import display as diag_display
resources = {
    "PEAK": "PEAK/PEAK",
}
path_to_model = "../PEAK.aird"
model = capellambse.MelodyModel(path_to_model, resources=resources)
from capella_tools import Pub4C
# Instantiate the class with the traceability file
traceability_store = Pub4C.Traceability_Store("../PEAK/traceability")
# Out:
# Warning: File '../PEAK/traceability' does not exist.

# %% [markdown]
# ## 🔄 Embedding Generation Process

# %%
from capella_tools  import capella_embeddings_manager

# Generate embeddings for all objects
model_embedding_manager = capella_embeddings_manager.EmbeddingManager()

embedding_file = "embeddings.json" 
model_embedding_manager.set_files( path_to_model , embedding_file)

model_embedding_manager.create_model_embeddings(model)
# Out:
# ✅ EmbeddingManager initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: https://api.openai.com/v1
# 🤖 Model: gpt-4o
# Loading embeddings
# embeddings loaded.

# %% [markdown]
# ## 🎯 Prompt for System Model Element Analysis

# %%
selected_objects = model_embedding_manager.query_and_select_top_objects("[LCBD] PEAK", top_n=1)
# Out:
# This is a list of ranked Objects Based on Query:
# Index: 0, Name: [LCBD] PEAK with Requirements, Similarity: 0.69, Type: Diagram, Phase: Logical Architecture LA, Source: , Target:

# %% [markdown]
# ## 📝 Generate Structured Input File

# %%
#Workflow


from capella_tools import capellambse_yaml_manager

yaml_handler = capellambse_yaml_manager.CapellaYAMLHandler()
   
#Generate YAML for the logical component and append to the file
for object in  selected_objects : 
    if object["type"] == "Diagram" :
        yaml_handler.generate_yaml(model.by_uuid(object["uuid"]))  
    else:
        yaml_handler.generate_yaml( model.search(object["type"]).by_uuid(object["uuid"]))


yaml_handler.generate_traceability_related_objects(model,traceability_store)

#yaml_handler.display()
yaml_handler.generate_yaml_referenced_objects()
#yaml_handler.display()

yaml_handler.write_output_file()

# %%
for object in  selected_objects : 
    #print(object)
    if object["type"] == "Diagram" :
        diagram = model.by_uuid(object["uuid"])
        #display(diagram)
    else:
        obj = model.search(object["type"]).by_uuid(object["uuid"])
        capellambse_helper.display_context_diagram(obj)

# %% [markdown]
# ## 💬 Predefined Prompts for Analysis

# %%
import os
from openai import OpenAI
from IPython.core.display import HTML
from IPython.display import display, clear_output, Markdown
from capella_tools  import Open_AI_RAG_manager
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.

# %% [markdown]
# ## ⚙️ Execute Followup Prompts

# %%
# Step 1: Get YAML content
yaml_content = yaml_handler.get_yaml_content()

# Step 2: Invoke ChatGPT for analysis
analyzer = Open_AI_RAG_manager.ChatGPTAnalyzer(yaml_content)
prompt = """
#Context#
The diagram represents a architecture developed by Attribure Driven Design (ADD).
The diagram represent an Architecture Driver as a requirement with [AD] in it name. It is releated to components and allocated functions. 
The diagrom is implemented with the ARCADIA method. 

#Role# 
Creating content for System Engineering lesson that decribes the diagram implementing ADD.

#Task#
For the diagram 
 Highlight the requirement denoted as a architecute driver with [AD} and it relation to logical components. 

Additional Requirements:
- Produce a summary of the diagram approriate to integration into an online lesson.
- Make the tone pleasant.
- The output should be formatted for easy cutting and pasting into a plain text window.
"""



analyzer.follow_up_prompt(prompt)
chatgpt_response = analyzer.get_response()
# Out:
# ✅ ChatGPTAnalyzer initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: https://api.openai.com/v1
# 🤖 Model: gpt-4o
# **Your prompt:**
# #Context#
# The diagram represents a architecture developed by Attribure Driven Design (ADD).
# The diagram represent an Architecture Driver as a requirement with [AD] in it name. It is releated to components and allocated functions.
# The diagrom is implemented with the ARCADIA method.
#
# #Role#
# Creating content for System Engineering lesson that decribes the diagram implementing ADD.
#
# #Task#
# For the diagram
#  Highlight the requirement denoted as a architecute driver with [AD} and it relation to logical components.
#
# Additional Requirements:
# - Produce a summary of the diagram approriate to integration into an online lesson.
# - Make the tone pleasant.
# - The output should be formatted for easy cutting and pasting into a plain text window.
# **Response:**
#
# # System Engineering Lesson: Understanding Architecture Drivers in System Design
#
# ## Introduction
#
# Welcome to this lesson on system architecture, where we explore the concept of Architecture Drivers (AD) and their role in system design. In this lesson, we will delve into a diagram that represents an architecture developed using Attribute Driven Design (ADD) and implemented with the ARCADIA method. Our focus will be on understanding the requirements denoted as architecture drivers and their relationships with logical components.
#
# ## Architecture Drivers (AD) and Their Relationships
#
# In the diagram, architecture drivers are represented as requirements with the prefix [AD] in their names. These drivers are crucial as they guide the design and development of the system architecture. Let's highlight the key architecture drivers and their relationships with logical components:
#
# 1. **[AD] 1. Compromised Power Infrastructure**
#    - **Related Components:**
#      - PEAK
#      - Primary Power Source
#      - Secondary Power Source
#      - Monitor
#      - Switch
#
# 2. **[AD] 2. Life Critical Services Such as Water**
#    - **Related Components:**
#      - PEAK
#      - Water Purification
#      - Water Filtration
#
# 3. **[AD] 3. Remote Assessment of Situation**
#    - **Related Components:**
#      - PEAK
#      - Smart Phones (Cellular)
#      - Unmanned Air Vehicle
#
# 4. **[AD] 4. Communication and Information Sharing**
#    - **Related Components:**
#      - PEAK
#
# 5. **[AD] 5. Exportable to Foreign Nation**
#    - **Related Components:**
#      - PEAK
#
# 6. **[AD] 6. Rapidly Deployable**
#    - **Related Components:**
#      - PEAK
#
# ## Summary
#
# This diagram provides a comprehensive view of how architecture drivers influence the design of a system. Each [AD] requirement is linked to specific logical components, ensuring that the system meets its intended goals and functions effectively. By understanding these relationships, system engineers can create robust architectures that address critical requirements and enhance system performance.
#
# We hope this lesson has provided you with valuable insights into the role of architecture drivers in system design. Remember, a well-defined architecture is the backbone of any successful system, and understanding these drivers is key to achieving that success.
#
# Feel free to integrate this content into your online lessons, and let your students explore the fascinating world of system architecture with a pleasant and engaging tone!
# **Token Usage Info:**
#
# Tokens used: prompt=58205, completion=497, total=58702

# %%
# Step 1: Get YAML content
yaml_content = yaml_handler.get_yaml_content()

# Step 2: Invoke ChatGPT for analysis
analyzer = Open_AI_RAG_manager.ChatGPTAnalyzer(yaml_content)
prompt = """
Analyze the provided YAML file and generate output formatted as .html.

For each diagram contained in the YAML:
- Clearly state the name of the diagram.
- Decribe the setting on the diagram with respect ARCADIA method and phase to which the diagram belongs (e.g., Operational Analysis, System Analysis, etc.).
- Focus on the Operational Process elements that appear on the diagram:
  - Provide a structured description of the operational process based on in involved activties and functional exchanges.
  - Note the owner of activities since they are performing them.

Additional Requirements:
- Ensure the description is clear, concise, and accessible for someone who is visually impaired.
- The output should be formatted for easy cutting and pasting into a plain text window.
"""


display(Markdown(f"\n\n**Prompt:**\n{prompt}"))
analyzer.follow_up_prompt(prompt)
chatgpt_response = analyzer.get_response()
# Out:
# ✅ ChatGPTAnalyzer initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: https://api.openai.com/v1
# 🤖 Model: gpt-4o
# **Prompt:**
#
# Analyze the provided YAML file and generate output formatted as .html.
#
# For each diagram contained in the YAML:
# - Clearly state the name of the diagram.
# - Decribe the setting on the diagram with respect ARCADIA method and phase to which the diagram belongs (e.g., Operational Analysis, System Analysis, etc.).
# - Focus on the Operational Process elements that appear on the diagram:
#   - Provide a structured description of the operational process based on in involved activties and functional exchanges.
#   - Note the owner of activities since they are performing them.
#
# Additional Requirements:
# - Ensure the description is clear, concise, and accessible for someone who is visually impaired.
# - The output should be formatted for easy cutting and pasting into a plain text window.
# **Your prompt:**
# Analyze the provided YAML file and generate output formatted as .html.
#
# For each diagram contained in the YAML:
# - Clearly state the name of the diagram.
# - Decribe the setting on the diagram with respect ARCADIA method and phase to which the diagram belongs (e.g., Operational Analysis, System Analysis, etc.).
# - Focus on the Operational Process elements that appear on the diagram:
#   - Provide a structured description of the operational process based on in involved activties and functional exchanges.
#   - Note the owner of activities since they are performing them.
#
# Additional Requirements:
# - Ensure the description is clear, concise, and accessible for someone who is visually impaired.
# - The output should be formatted for easy cutting and pasting into a plain text window.
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>YAML Diagram Analysis</title>
#
# </head>
# <body>
# <h1>YAML Diagram Analysis</h1>
# <h2>Diagram: [LCBD] PEAK with Requirements</h2>
# <p><strong>Setting:</strong> This diagram is part of the System Analysis phase of the ARCADIA method. It focuses on the logical architecture of the system, detailing the components and their interactions.</p>
# <h3>Operational Process Elements</h3>
# <ul>
# <li>
# <strong>Operational Process:</strong> The diagram outlines the interactions between various subsystems such as Water Subsystem, Power Sub-System, Communication Subsystem, and Situational Awareness Sub-System.
#         </li>
# <li>
# <strong>Activities and Functional Exchanges:</strong>
# <ul>
# <li>
# <strong>Water Subsystem:</strong>
# <ul>
# <li>Activity: Water Purification</li>
# <li>Functional Exchange: Receives power from Power Sub-System.</li>
# </ul>
# </li>
# <li>
# <strong>Power Sub-System:</strong>
# <ul>
# <li>Activity: Power Distribution</li>
# <li>Functional Exchange: Provides power to Water Subsystem and Situational Awareness Sub-System.</li>
# </ul>
# </li>
# <li>
# <strong>Communication Subsystem:</strong>
# <ul>
# <li>Activity: Relay Data</li>
# <li>Functional Exchange: Sends data to Remote Coordination Station.</li>
# </ul>
# </li>
# <li>
# <strong>Situational Awareness Sub-System:</strong>
# <ul>
# <li>Activity: Gather Environment Data</li>
# <li>Functional Exchange: Transmits situational data to VSAT Station.</li>
# </ul>
# </li>
# </ul>
# </li>
# <li>
# <strong>Owners of Activities:</strong>
# <ul>
# <li>Water Purification is owned by the Water Subsystem.</li>
# <li>Power Distribution is owned by the Power Sub-System.</li>
# <li>Relay Data is owned by the Communication Subsystem.</li>
# <li>Gather Environment Data is owned by the Situational Awareness Sub-System.</li>
# </ul>
# </li>
# </ul>
# </body>
# </html>
# ```
#
# This HTML document provides a structured analysis of the diagram "[LCBD] PEAK with Requirements" from the YAML file. It describes the setting of the diagram within the ARCADIA method, focusing on the System Analysis phase. The operational process elements are detailed, including activities, functional exchanges, and the owners of these activities, making it accessible for someone who is visually impaired.
# **Token Usage Info:**
#
# Tokens used: prompt=58202, completion=737, total=58939

# %%
print("Done")
# Out:
# Done

# %% [markdown]
# #
