# %% [markdown]
# # System Engineering Model Analyzer:
# ## Leveraging AI for System Engineering models

# %% [markdown]
# ### Model-Specific Code (Do Not Modify)
#
# This section contains code that is specific to the system model. It is updated only when the model is changed and should not require user modifications under normal circumstances.
#
# If a new model is introduced, ensure this section is reviewed and updated as needed.

# %%
#!pip install --upgrade git+https://github.com/tkSDISW/Capella_Tools 
import capellambse.decl

from capella_tools import capellambse_helper

from IPython import display as diag_display
resources = {
    "PEAK": "PEAK/PEAK",
}
path_to_model = "../PEAK.aird"
model = capellambse.MelodyModel(path_to_model, resources=resources)
from capella_tools import Pub4C
# Instantiate the class with the traceability file
traceability_store = Pub4C.Traceability_Store("../PEAK/traceability")
# Out:
# Warning: File '../PEAK/traceability' does not exist.

# %% [markdown]
# ## 🔄 Embedding Generation Process

# %%
from capella_tools  import capella_embeddings_manager

# Generate embeddings for all objects
model_embedding_manager = capella_embeddings_manager.EmbeddingManager()

embedding_file = "embeddings.json" 
model_embedding_manager.set_files( path_to_model , embedding_file)

model_embedding_manager.create_model_embeddings(model)
# Out:
# ✅ EmbeddingManager initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: https://api.openai.com/v1
# 🤖 Model: gpt-4o
# Loading embeddings
# embeddings loaded.

# %% [markdown]
# ## 🎯 Prompt for System Model Element Analysis

# %%
selected_objects = model_embedding_manager.query_and_select_top_objects("[LAB] Water Generation ADD", top_n=1)
# Out:
# This is a list of ranked Objects Based on Query:
# Index: 0, Name: [LAB] Water Generation ADD, Similarity: 0.82, Type: Diagram, Phase: Logical Architecture LA, Source: , Target:

# %% [markdown]
# ## 📝 Generate Structured Input File

# %%
#Workflow


from capella_tools import capellambse_yaml_manager

yaml_handler = capellambse_yaml_manager.CapellaYAMLHandler()
   
#Generate YAML for the logical component and append to the file
for object in  selected_objects : 
    if object["type"] == "Diagram" :
        yaml_handler.generate_yaml(model.by_uuid(object["uuid"]))  
    else:
        yaml_handler.generate_yaml( model.search(object["type"]).by_uuid(object["uuid"]))


yaml_handler.generate_traceability_related_objects(model,traceability_store)

#yaml_handler.display()
yaml_handler.generate_yaml_referenced_objects()
#yaml_handler.display()

yaml_handler.write_output_file()

# %%
for object in  selected_objects : 
    #print(object)
    if object["type"] == "Diagram" :
        diagram = model.by_uuid(object["uuid"])
        #display(diagram)
    else:
        obj = model.search(object["type"]).by_uuid(object["uuid"])
        capellambse_helper.display_context_diagram(obj)

# %% [markdown]
# ## 💬 Predefined Prompts for Analysis

# %%
import os
from openai import OpenAI
from IPython.core.display import HTML
from IPython.display import display, clear_output, Markdown
from capella_tools  import Open_AI_RAG_manager
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.

# %% [markdown]
# ## ⚙️ Execute Followup Prompts

# %%
# Step 1: Get YAML content
yaml_content = yaml_handler.get_yaml_content()

# Step 2: Invoke ChatGPT for analysis
analyzer = Open_AI_RAG_manager.ChatGPTAnalyzer(yaml_content)
prompt = """
#Context#
The diagram represents a architecture developed by Attribure Driven Design (ADD).
The diagram represent an Architecture Driver as a requirement with [AD] in it name. It is releated to components and allocated functions. 
The diagrom is implemented with the ARCADIA method. 

#Role# 
Creating content for System Engineering lesson that decribes the diagram implementing ADD.

#Task#
For the diagram 
 Highlight the requirement denoted as a architecute driver with [AD} and it relation to logical components. 
 Higlight how the Functional Chain depicted is implemented but its involved functions and each functions allocated component, and if the component had been impacted by a related architecture driver. 

Additional Requirements:
- Produce a summary of the diagram approriate to integration into an online lesson.
- Make the tone pleasant.
- The output should be formatted for easy cutting and pasting into a plain text window.
"""



analyzer.follow_up_prompt(prompt)
chatgpt_response = analyzer.get_response()
# Out:
# ✅ ChatGPTAnalyzer initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: https://api.openai.com/v1
# 🤖 Model: gpt-4o
# **Your prompt:**
# #Context#
# The diagram represents a architecture developed by Attribure Driven Design (ADD).
# The diagram represent an Architecture Driver as a requirement with [AD] in it name. It is releated to components and allocated functions.
# The diagrom is implemented with the ARCADIA method.
#
# #Role#
# Creating content for System Engineering lesson that decribes the diagram implementing ADD.
#
# #Task#
# For the diagram
#  Highlight the requirement denoted as a architecute driver with [AD} and it relation to logical components.
#  Higlight how the Functional Chain depicted is implemented but its involved functions and each functions allocated component, and if the component had been impacted by a related architecture driver.
#
# Additional Requirements:
# - Produce a summary of the diagram approriate to integration into an online lesson.
# - Make the tone pleasant.
# - The output should be formatted for easy cutting and pasting into a plain text window.
# **Response:**
#
# # System Engineering Lesson: Understanding Architecture Drivers and Functional Chains in System Design
#
# ## Introduction
# Welcome to this lesson on system engineering, where we explore the intricacies of architecture drivers and functional chains within a system design. This lesson will guide you through understanding how requirements, denoted as architecture drivers, relate to logical components and how functional chains are implemented through their involved functions and allocated components.
#
# ## Architecture Drivers: Requirements with [AD]
# In the system model, architecture drivers are specific requirements that significantly influence the design and structure of the system. These are denoted with [AD] in their names. Let's highlight some key architecture drivers and their relationships with logical components:
#
# 1. **[AD] 1. Compromised power infrastructure**
#    - **Related Components:**
#      - Primary Power Source
#      - Secondary Power Source
#      - Monitor
#      - Switch
#    - **Impact:** This driver ensures that the system can handle power infrastructure challenges by integrating reliable power sources and monitoring systems.
#
# 2. **[AD] 2. Life critical services such as water**
#    - **Related Components:**
#      - Water Filtration
#      - Water Purification
#    - **Impact:** This driver emphasizes the importance of maintaining life-critical services, ensuring that water systems are robust and reliable.
#
# 3. **[AD] 3. Remote assessment of situation**
#    - **Related Components:**
#      - PEAK
#      - Smart Phones (Cellular)
#      - Unmanned Air Vehicle
#    - **Impact:** This driver focuses on enabling remote assessment capabilities, integrating components that facilitate situational awareness and data collection.
#
# 4. **[AD] 4. Communication and information sharing**
#    - **Related Components:**
#      - PEAK
#    - **Impact:** This driver ensures effective communication and information sharing across the system, crucial for coordination and response.
#
# 5. **[AD] 5. Exportable to Foreign Nation**
#    - **Related Components:**
#      - PEAK
#    - **Impact:** This driver highlights the system's adaptability and exportability, ensuring it meets international standards.
#
# 6. **[AD] 6. Rapidly deployable**
#    - **Related Components:**
#      - PEAK
#    - **Impact:** This driver ensures the system can be quickly deployed, enhancing its responsiveness in critical situations.
#
# ## Functional Chain Implementation
# The functional chain in the system model is a sequence of functions that work together to achieve a specific goal. Let's explore how this is implemented:
#
# ### Water Management Functional Chain
# - **Involved Functions:**
#   1. **Receive Water**
#      - **Allocated Component:** Aid Personnel, First Responders, Local Population, Operational User Community
#      - **Architecture Driver Impact:** [AD] 2. Life critical services such as water
#   2. **Operate System**
#      - **Allocated Component:** Operational User Community
#      - **Architecture Driver Impact:** [AD] 3. Remote assessment of situation
#   3. **Provide Water**
#      - **Allocated Component:** Environment
#      - **Architecture Driver Impact:** [AD] 2. Life critical services such as water
#   4. **Filter undesired elements from treated water**
#      - **Allocated Component:** Water Filtration
#      - **Architecture Driver Impact:** [AD] 2. Life critical services such as water
#   5. **Process water**
#      - **Allocated Component:** Water Purification
#      - **Architecture Driver Impact:** [AD] 2. Life critical services such as water
#   6. **Sense and Pump Water**
#      - **Allocated Component:** Pump and Controls
#      - **Architecture Driver Impact:** [AD] 1. Compromised power infrastructure
#   7. **Dipense potable water (via Spigot/ Faucets)**
#      - **Allocated Component:** Storage Container
#      - **Architecture Driver Impact:** [AD] 2. Life critical services such as water
#
# - **Summary:** The Water Management functional chain is a critical sequence that ensures the delivery of potable water. Each function is carefully allocated to components that are influenced by architecture drivers, ensuring the system's reliability and efficiency in providing life-critical services.
#
# ## Conclusion
# In this lesson, we've explored how architecture drivers influence system design and how functional chains are implemented through their involved functions and allocated components. Understanding these relationships is crucial for designing robust and efficient systems that meet critical requirements. We hope this lesson has provided valuable insights into the intricacies of system engineering.
# **Token Usage Info:**
#
# Tokens used: prompt=84587, completion=914, total=85501

# %%
# Step 1: Get YAML content
yaml_content = yaml_handler.get_yaml_content()

# Step 2: Invoke ChatGPT for analysis
analyzer = Open_AI_RAG_manager.ChatGPTAnalyzer(yaml_content)
prompt = """
Analyze the provided YAML file and generate output formatted as .html.

For each diagram contained in the YAML:
- Clearly state the name of the diagram.
- Decribe the setting on the diagram with respect ARCADIA method and phase to which the diagram belongs (e.g., Operational Analysis, System Analysis, etc.).
- Focus on the Operational Process elements that appear on the diagram:
  - Provide a structured description of the operational process based on in involved activties and functional exchanges.
  - Note the owner of activities since they are performing them.

Additional Requirements:
- Ensure the description is clear, concise, and accessible for someone who is visually impaired.
- The output should be formatted for easy cutting and pasting into a plain text window.
"""


display(Markdown(f"\n\n**Prompt:**\n{prompt}"))
analyzer.follow_up_prompt(prompt)
chatgpt_response = analyzer.get_response()
# Out:
# ✅ ChatGPTAnalyzer initialized
# 🔐 API Key: Loaded from secrets
# 🌐 Base URL: https://api.openai.com/v1
# 🤖 Model: gpt-4o
# **Prompt:**
#
# Analyze the provided YAML file and generate output formatted as .html.
#
# For each diagram contained in the YAML:
# - Clearly state the name of the diagram.
# - Decribe the setting on the diagram with respect ARCADIA method and phase to which the diagram belongs (e.g., Operational Analysis, System Analysis, etc.).
# - Focus on the Operational Process elements that appear on the diagram:
#   - Provide a structured description of the operational process based on in involved activties and functional exchanges.
#   - Note the owner of activities since they are performing them.
#
# Additional Requirements:
# - Ensure the description is clear, concise, and accessible for someone who is visually impaired.
# - The output should be formatted for easy cutting and pasting into a plain text window.
# **Your prompt:**
# Analyze the provided YAML file and generate output formatted as .html.
#
# For each diagram contained in the YAML:
# - Clearly state the name of the diagram.
# - Decribe the setting on the diagram with respect ARCADIA method and phase to which the diagram belongs (e.g., Operational Analysis, System Analysis, etc.).
# - Focus on the Operational Process elements that appear on the diagram:
#   - Provide a structured description of the operational process based on in involved activties and functional exchanges.
#   - Note the owner of activities since they are performing them.
#
# Additional Requirements:
# - Ensure the description is clear, concise, and accessible for someone who is visually impaired.
# - The output should be formatted for easy cutting and pasting into a plain text window.
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>YAML Diagram Analysis</title>
#
# </head>
# <body>
# <h1>YAML Diagram Analysis</h1>
# <h2>Diagram: [LAB] Water Generation ADD</h2>
# <p><strong>Setting:</strong> This diagram belongs to the System Analysis phase of the ARCADIA method. It focuses on the system's architecture and its interactions.</p>
# <h3>Operational Process Elements</h3>
# <ul>
# <li>
# <strong>Water Management</strong>
# <ul>
# <li><strong>Owner:</strong> Water Management</li>
# <li><strong>Activities:</strong>
# <ul>
# <li>Receive Water</li>
# <li>Operate System</li>
# <li>Provide Water</li>
# <li>Dipense potable water (via Spigot/ Faucets)</li>
# <li>Filter undesired elements from treated water</li>
# <li>Sense and Pump Water</li>
# <li>Process water</li>
# </ul>
# </li>
# <li><strong>Functional Exchanges:</strong>
# <ul>
# <li>Water</li>
# <li>Filtered Water</li>
# <li>Control Pump</li>
# <li>Purified Water</li>
# </ul>
# </li>
# </ul>
# </li>
# <li>
# <strong>PEAK</strong>
# <ul>
# <li><strong>Owner:</strong> PEAK</li>
# <li><strong>Activities:</strong> Reference to PEAK component</li>
# </ul>
# </li>
# <li>
# <strong>Water Subsystem</strong>
# <ul>
# <li><strong>Owner:</strong> Water Subsystem</li>
# <li><strong>Activities:</strong> Reference to Water Subsystem component</li>
# </ul>
# </li>
# <li>
# <strong>Water Purification</strong>
# <ul>
# <li><strong>Owner:</strong> Water Purification</li>
# <li><strong>Activities:</strong> Reference to Water Purification component</li>
# </ul>
# </li>
# <li>
# <strong>Process water</strong>
# <ul>
# <li><strong>Owner:</strong> Water Purification</li>
# <li><strong>Activities:</strong> Purify bacteria from water</li>
# <li><strong>Functional Exchanges:</strong>
# <ul>
# <li>Filtered Water</li>
# <li>Purified Water</li>
# <li>Sense Water</li>
# </ul>
# </li>
# </ul>
# </li>
# <li>
# <strong>Water Filtration</strong>
# <ul>
# <li><strong>Owner:</strong> Water Filtration</li>
# <li><strong>Activities:</strong> Reference to Water Filtration component</li>
# </ul>
# </li>
# <li>
# <strong>Filter undesired elements from treated water</strong>
# <ul>
# <li><strong>Owner:</strong> Water Filtration</li>
# <li><strong>Activities:</strong> Pump and filter the water</li>
# <li><strong>Functional Exchanges:</strong>
# <ul>
# <li>Control Pump</li>
# <li>Filtered Water</li>
# </ul>
# </li>
# </ul>
# </li>
# <li>
# <strong>Storage Container</strong>
# <ul>
# <li><strong>Owner:</strong> Storage Container</li>
# <li><strong>Activities:</strong> Reference to Storage Container component</li>
# </ul>
# </li>
# <li>
# <strong>Dipense potable water (via Spigot/ Faucets)</strong>
# <ul>
# <li><strong>Owner:</strong> Storage Container</li>
# <li><strong>Activities:</strong> Store in a vessel to be distributed</li>
# <li><strong>Functional Exchanges:</strong>
# <ul>
# <li>Purified Water</li>
# <li>Filtered Water</li>
# <li>Water</li>
# <li>Sense Level</li>
# </ul>
# </li>
# </ul>
# </li>
# <li>
# <strong>Pump and Controls</strong>
# <ul>
# <li><strong>Owner:</strong> Pump and Controls</li>
# <li><strong>Activities:</strong> Reference to Pump and Controls component</li>
# </ul>
# </li>
# <li>
# <strong>Sense and Pump Water</strong>
# <ul>
# <li><strong>Owner:</strong> Pump and Controls</li>
# <li><strong>Activities:</strong> Sense and pump water</li>
# <li><strong>Functional Exchanges:</strong>
# <ul>
# <li>Control Pump</li>
# </ul>
# </li>
# </ul>
# </li>
# <li>
# <strong>Power Sub-System</strong>
# <ul>
# <li><strong>Owner:</strong> Power Sub-System</li>
# <li><strong>Activities:</strong> Reference to Power Sub-System component</li>
# </ul>
# </li>
# </ul>
# </body>
# </html>
# ```
# **Token Usage Info:**
#
# Tokens used: prompt=84551, completion=1320, total=85871

# %%
print("Done")
# Out:
# Done

# %% [markdown]
# #
